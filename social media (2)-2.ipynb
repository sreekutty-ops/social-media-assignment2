# %% [markdown]
# ## 1. Data Collection

# %%
# Assignment 2 : Choose Your Own Analysis
# Group 18


# Data handling
import pandas as pd   # Used for reading, storing, cleaning, and analysing data in table format, such as rows and columns.
import numpy as np    # Used for numerical operations, particularly when dealing with calculations, arrays, and missing data.
import json           # Used to read and process JSON data, a popular format for information gathered from YouTube and other APIs.


# Text processing 
import re              # Used to remove links, numerals, and special characters from text using patterns.
import string          # Makes punctuation symbols accessible, which aids in removing punctuation from text.

#  NLP 
import nltk           # Natural Language Toolkit, used for basic text analysis tasks.

# Used to eliminate words that don't add much meaning, such as "the," "is," and "and."
from nltk.corpus import stopwords 

# Used to determine if a comment is neutral, negative, or favorable.
from nltk.sentiment import SentimentIntensityAnalyzer

# Before utilizing the necessary NLTK resources, download them once.

# Downloads the list of frequently used stopwords required for text cleaning.
nltk.download('stopwords')

# Downloads the VADER sentiment dictionary used for sentiment analysis.
nltk.download('vader_lexicon')

#  Tokenization 

# Used to determine how frequently users, words, or themes appear in the dataset.
from collections import Counter

# Topic modelling 

# Counts the frequency of words in cleaned text to translate it into numbers that machine learning algorithms can comprehend.
from sklearn.feature_extraction.text import CountVectorizer

# Used for topic modeling, which aids in identifying topics or hidden themes in the comments.
from sklearn.decomposition import LatentDirichletAllocation

# Network analysis 
# Used to build and examine networks, including connections between users, channels, and comments.
import networkx as nx

# Visualisation 

# Used to make simple charts and graphs to graphically illustrate the analysis.
import matplotlib.pyplot as plt

# Used to make statistical visualisations look cleaner and easier to understand.
import seaborn as sns

# wordcloud

# Used to produce a word cloud that visually displays the most common terms.
from wordcloud import WordCloud
# Import Patch to create custom legend entries for network visualisation
from matplotlib.patches import Patch
# Import Louvain community detection algorithm
# This is used to identify clusters (communities) of users in the network
import community as community_louvain
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sreelakshmi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/sreelakshmi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Tokenization and text preparation

#TweetTokenizer is particularly helpful for social media content since it handles emojis, hashtags, short forms, and informal language better. 
#Tokenization is used to divide text into smaller sections called tokens (words).

from nltk.tokenize import TweetTokenizer

#Common stopwords like "the," "is," and "and" that are typically 
#eliminated during text cleaning since they don't provide significant information are imported.
from nltk.corpus import stopwords

# Used to determine how frequently words, hashtags, or other objects appear in the dataset.
from collections import Counter

# Before utilizing the necessary NLTK resources, download them just once.

# Downloads the stopword dataset needed to exclude frequently occurring words.
nltk.download('stopwords')

# Downloads the Punkt tokenizer models needed for sentence and word tokenization.
nltk.download('punkt')

# Downloads additional Punkt tokenizer tables required in some newer NLTK versions.
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sreelakshmi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sreelakshmi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/sreelakshmi/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from googleapiclient.discovery import build
import time

# Storing the YouTube API key.
API_KEY = "AIzaSyDhuvjIsdyFU1C2z8_4EkbU4DloKx4JdVk"

def youtubeClient():
    # Creating a YouTube API client so we can send requests to YouTube.
    return build('youtube', 'v3', developerKey=API_KEY)


def fetchYoutubeData(searchQuery, maxVideos=50, maxCommentsPerVideo=100, outputFile='youtubeDataDump.json'):
    # Creating the API client that will be used throughout the function.
    client = youtubeClient()

    # Enables the function to take one or more search phrases.
    if isinstance(searchQuery, str):
        queries = [searchQuery]
    else:
        queries = searchQuery

    # Storing video IDs collected from the search results.
    videoIds = []

    # Storing basic video details such as title, channel name, and publish date.
    videoSnippets = {}

    # Maintains track of previously gathered videos to prevent duplication.
    seen_ids = set()

    # Looks for videos on YouTube that are relevant to each inquiry.
    for query in queries:
        # Gathers excess videos first because some might be eliminated during the filtering process.
        if len(videoIds) >= maxVideos * 2:  # collect 2x to allow for filtering
            break

        print(f" Searching for videos: {query}")

        # Sends YouTube a search request.
        searchResponse = client.search().list(
            q=query,
            part='snippet',
            type='video',
            order='viewCount',        # Gives popular videos that receive more interaction priority.
            maxResults=50,
            relevanceLanguage='en',   # Assists in concentrating on English-language content.
            regionCode='US'           # Provides additional search results that are relevant to the area.
        ).execute()

        # Examines every video that the search turned up.
        for item in searchResponse.get('items', []):
            vid = item['id']['videoId']

            # Only adds the video if it hasn't been gathered before.
            if vid not in seen_ids:
                seen_ids.add(vid)
                videoIds.append(vid)
                videoSnippets[vid] = item['snippet']

        print(f" Total unique videos so far: {len(videoIds)}")
        # In order to prevent sending requests too soon, a brief delay is included.
        time.sleep(0.5)

    # Retrieve statistics and filter videos with low engagement
    print(" Fetching video statistics...")

   # Keeps track of metrics like duration, views, likes, and comments.
    videoStats = {}

    # YouTube allows up to 50 video IDs in one statistics request.
    for i in range(0, len(videoIds), 50):
        batch = videoIds[i:i+50]

        # Requests duration information and statistics for every batch of videos.
        statsResponse = client.videos().list(
            id=','.join(batch),
            part='statistics,contentDetails'  # contentDetails for duration
        ).execute()

        # Saves each video's statistics.
        for item in statsResponse.get('items', []):
            videoStats[item['id']] = {
                'stats': item['statistics'],
                'duration': item['contentDetails']['duration']
            }

    
    def is_short(duration):
        # Determines if a video is likely to be a YouTube Short.
        # Shorts often last one minute or less.
        return 'H' not in duration and (
            'M' not in duration or duration in ['PT1M', 'PT0M']
        )

    # Only videos that satisfy our standards for quality are stored.
    filteredVideoIds = []
    for vid in videoIds:
        # Ignores videos that don't have statistics.
        if vid not in videoStats:
            continue
        stats = videoStats[vid]['stats']
        duration = videoStats[vid]['duration']
        # Provides figures for filtering by converting view and comment counts.
        comment_count = int(stats.get('commentCount', 0))
        view_count = int(stats.get('viewCount', 0))

        # Removes shorts and maintains videos with sufficient engagement.
        if comment_count >= 100 and view_count >= 10000 and not is_short(duration):
            filteredVideoIds.append(vid)

        #Ends when the necessary quantity of videos is gathered.
        if len(filteredVideoIds) >= maxVideos:
            break

    print(f" Videos after filtering: {len(filteredVideoIds)} (removed {len(videoIds) - len(filteredVideoIds)} low-quality videos)")

    
    # Fetching comments
    print(" Fetching comments...\n")

    # Storing the final dataset.
    videos = []

    # Collecting comments for each selected video.
    for videoId in filteredVideoIds:
        snippet = videoSnippets[videoId]
        stats = videoStats[videoId]['stats']

        # Creating a dictionary to store video-level information.
        video = {
            'title': snippet['title'],
            'videoId': videoId,
            'channelTitle': snippet['channelTitle'],
            'publishedAt': snippet['publishedAt'],
            'viewCount': int(stats.get('viewCount', 0)),
            'likeCount': int(stats.get('likeCount', 0)),
            'commentCount': int(stats.get('commentCount', 0)),
            'comments': []
        }

        try:
            comments_fetched = 0
            next_page_token = None

            print(f" {snippet['title'][:60]}...")

            # Continues to gather comments until the upper limit is attained.
            while comments_fetched < maxCommentsPerVideo:

                # Asks for high-level responses and opinions on the video.
                response = client.commentThreads().list(
                    videoId=videoId,
                    part='snippet,replies',
                    maxResults=100,
                    pageToken=next_page_token,
                    textFormat='plainText'
                ).execute()

                # Examines every comment thread.
                for item in response.get('items', []):
                    topComment = item['snippet']['topLevelComment']['snippet']

                    # The main comment is saved.
                    video['comments'].append({
                        'author': topComment['authorDisplayName'],
                        'text': topComment['textDisplay'],
                        'publishedAt': topComment['publishedAt'],
                        'likeCount': topComment.get('likeCount', 0),
                        'reply_to': None
                    })
                    comments_fetched += 1

                    # If there are responses to the primary comment, they are saved.
                    if 'replies' in item:
                        for reply in item['replies']['comments']:
                            r = reply['snippet']
                            video['comments'].append({
                                'author': r['authorDisplayName'],
                                'text': r['textDisplay'],
                                'publishedAt': r['publishedAt'],
                                'likeCount': r.get('likeCount', 0),
                                'reply_to': topComment['authorDisplayName']
                            })
                            comments_fetched += 1

                # If available, continues to the next page of comments.
                next_page_token = response.get('nextPageToken')

                # Stops when the number of comment pages is zero.
                if not next_page_token:
                    break

            print(f"   → {len(video['comments'])} comments\n")
            # To lessen API strain, a bit gap is added between videos.
            time.sleep(1)

        except Exception as e:
            # Ignores videos with disabled or unavailable comments.
            print(f"   → Skipped (comments disabled or error): {e}\n")
            continue  # skip disabled videos cleanly

        # Incorporates the finished video info into the final list.
        videos.append(video)

    # Maintains a single dictionary with all gathered videos and comments.
    data = {'videos': videos}

    # Creates a JSON file with the gathered dataset.
    with open(outputFile, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    # Determines how many comments were gathered overall.
    total_comments = sum(len(v['comments']) for v in videos)

    print("=====================================")
    print("Dataset saved!")
    print(f"Total videos: {len(videos)}")
    print(f"Total comments: {total_comments}")
    print("=====================================")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/google/api_core/_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.8.8). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/google/auth/__init__.py:52: FutureWarning: You are using a Python version 3.8 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.8"), FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/google/oauth2/__init__.py:38: FutureWarning: You are using a Python version 3.8 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.8"), FutureWarning)

# %%
#Run the YouTube data collecting feature, which looks for videos about doctors, 
# influencers, health advice, and misinformation.

fetchYoutubeData(
    # List of search terms used to get various viewpoints
    # connected to online disinformation and health communication.
    searchQuery=[
        "doctor debunks health influencer",
        "doctor reacts bad health advice",
        "doctor fact checks wellness influencer",
        "medical doctor debunks myths",
        "health influencer wrong advice",
        "wellness influencer dangerous advice",
        "influencer health misinformation",
        "doctor vs wellness influencer debate",
    ],
    maxVideos=60,
    maxCommentsPerVideo=150,
    outputFile="mental_health_dataset.json"
)
# Out:
#  Searching for videos: doctor debunks health influencer
#  Total unique videos so far: 50
#  Searching for videos: doctor reacts bad health advice
#  Total unique videos so far: 99
#  Searching for videos: doctor fact checks wellness influencer
#  Total unique videos so far: 105
#  Searching for videos: medical doctor debunks myths
#  Total unique videos so far: 150
#  Fetching video statistics...
#  Videos after filtering: 60 (removed 90 low-quality videos)
#  Fetching comments...
#
#  Doctor Fact-Checks TikTok Nutrition Advice...
#    → 208 comments
#
#  Doctor Blocks Me For Correcting Him...
#    → 211 comments
#
#  Doctor Reacts To Scary TikTok Health Advice...
#    → 208 comments
#
#  TikTok &quot;Health&quot; Products You Should NEVER Buy...
#    → 221 comments
#
#  Doctor Reacts To TERRIBLE TikTok Medical Advice...
#    → 213 comments
#
#  The Truth About Detox Smoothies...
#    → 204 comments
#
#  The Truth About Lemon Water 😲...
#    → 207 comments
#
#  How “Health Gurus” Trick You ft Gary Brecka...
#    → 214 comments
#
#  Debunking the worst haircare advice on TikTok...
#    → 213 comments
#
#  Here&#39;s Why Doctor&#39;s NEVER Drink Detox Tea...
#    → 239 comments
#
#  Debunking HPV Myths...
#    → 235 comments
#
#  Gynecologist Debunks Viral Birth Control LIES...
#    → 248 comments
#
#  Uncovering Corruption From Spiritual Leaders &amp; Health Ex...
#    → 221 comments
#
#  Scientist debunks: The worst skincare misinformation on TikT...
#    → 231 comments
#
#  Has This Famous Carnivore Influencer Been Lying? - Doctor Re...
#    → 228 comments
#
#  “Influencers” don’t understand “raw milk”...
#    → 249 comments
#
#  Gallbladder Flush - The true science behind the myth...
#    → 294 comments
#
#  Tongkat Ali - How Health Influencers SCAM You...
#    → 234 comments
#
#  Are Doctor Influencers POISONING Medicine? | Neurosurgeon vs...
#    → 237 comments
#
#  Un médecin débunke vos influenceurs préférés !...
#    → 152 comments
#
#  Fridge Vs Influencers. Zeher Kismein Hai?...
#    → 159 comments
#
#  Dieta Carnívora: A Verdade Científica que os Influencers Esc...
#    → 256 comments
#
#  I DESTROYED These “Doctors” Who Tried to Debunk the Carnivor...
#    → 105 comments
#
#  Real Doctor Reacts to THE GOOD DOCTOR | Medical Drama Review...
#    → 220 comments
#
#  Doctor Reacts To Painful TikToks...
#    → 209 comments
#
#  Real Doctor Reacts To Painful WWE Injuries...
#    → 233 comments
#
#  Doctor Reacts To DRAMATIC Lifeguard Rescues...
#    → 218 comments
#
#  Doctor Reacts To Ridiculous 5-Minute Crafts Videos...
#    → 201 comments
#
#  The Harsh Reality Of Being 800 Pounds | Doctor Reacts...
#    → 225 comments
#
#  Ridiculously Absurd 5-Minute Crafts “Health Hacks”...
#    → 203 comments
#
#  TikToks Only A Doctor Can Explain...
#    → 218 comments
#
#  Doctor Reacts To The Worst TikTok Medical Advice...
#    → 211 comments
#
#  Doctor Reacts To The Most Extreme Diets | Freaky Eaters...
#    → 211 comments
#
#  ER Doctor REACTS to Wildest Far Cry Healing Animations...
#    → 212 comments
#
#  Doctor Reacts to The Most Dangerous MrBeast Stunts...
#    → 238 comments
#
#  TikToks Your Doctor Warned You About...
#    → 205 comments
#
#  Doctor Reacts To Cringey Dhar Mann Videos...
#    → 207 comments
#
#  Real Doctor Reacts to HOUSE M.D. | Medical Drama Review | Do...
#    → 224 comments
#
#  The WORST 5-Minute Crafts “Health Hacks”...
#    → 204 comments
#
#  Health TikToks To Never Show Your Doctor...
#    → 207 comments
#
#  Doctor Mike Reacts To House MD | Compilation...
#    → 214 comments
#
#  Doctor and Lawyer React To Grey’s Anatomy Malpractice Episod...
#    → 222 comments
#
#  Doctor Reacts To Family Guy Medical Scenes...
#    → 220 comments
#
#  Doctor Reacts To Painful Medical Memes...
#    → 207 comments
#
#  Doctor Reacts To Home Alone Injuries...
#    → 204 comments
#
#  Doctor Reacts To The Wildest TikToks...
#    → 228 comments
#
#  Doctor Reacts To Hilarious South Park Medical Scenes...
#    → 227 comments
#
#  First Aid Hacks That Should Be Illegal...
#    → 204 comments
#
#  Doctor Reacts to HILARIOUS TikToks...
#    → 219 comments
#
#  Doctor reacts to super satisfying pimple pops! #dermreacts #...
#    → 212 comments
#
#  Real Doctor Reacts to DOC MCSTUFFINS...
#    → 210 comments
#
#  Doctor Reacts To Bizarre Health &quot;Hack&quot; Videos...
#    → 204 comments
#
#  Doctors React To Horrifying Old Medical Devices...
#    → 208 comments
#
#  Doctor Reacts To Extreme Medical Conditions...
#    → 218 comments
#
#  Doctor Reacts To Rough Soccer Injuries...
#    → 216 comments
#
#  Fact-Checking MrWhoseTheBoss Health Hacks...
#    → 231 comments
#
#  Biomedical Scientist Answers More Pseudoscience Questions | ...
#    → 254 comments
#
#  Debunking the myths of OCD - Natascha M. Santos...
#    → 237 comments
#
#  Can you masturbate too much?! | Urologist DEBUNKS 6 Masturba...
#    → 233 comments
#
#  Doctor Fact-Checks Grandma’s Medical Advice...
#    → 222 comments
#
# =====================================
# Dataset saved!
# Total videos: 60
# Total comments: 13023
# =====================================

# %%
# Make a list of search terms related to influencer-driven health conversations, 
# alternative health advice, and wellness.

queries = [
    "wellness influencer health tips",
    "carnivore diet influencer",
    "natural health remedies influencer",
    "detox cleanse health influencer",
    "supplement health influencer",
    "holistic health influencer advice",
    "anti vaccine influencer",
    "raw milk benefits influencer",
    "biohacking health influencer",
    "gary brecka health advice"
]


# Use the influencer-related queries to run the YouTube data gathering procedure.
fetchYoutubeData(
    searchQuery=queries,
    maxVideos=30,           # 3 per query × 10 queries = 30
    maxCommentsPerVideo=150,
    outputFile="influencer_dataset.json"
)
# Out:
#  Searching for videos: wellness influencer health tips
#  Total unique videos so far: 50
#  Searching for videos: carnivore diet influencer
#  Total unique videos so far: 100
#  Fetching video statistics...
#  Videos after filtering: 30 (removed 70 low-quality videos)
#  Fetching comments...
#
#  TikTok &quot;Health&quot; Products You Should NEVER Buy...
#    → 221 comments
#
#  TOP 1% WOMAN ROUTINE: How I Stay Productive, Healthy &amp; B...
#    → 206 comments
#
#  Nitesh Soni Exposed | Reality of Fitness Influencers | Dt.Bh...
#    → 204 comments
#
#  3 Red Flags of Health Influencers: Who I Actually Watch vs. ...
#    → 209 comments
#
#  Unhinged Wellness Influencers...
#    → 217 comments
#
#  NUTRITION TRUTHS That Wellness Influencers ❌ DON&#39;T ❌ Wan...
#    → 217 comments
#
#  Unhinged Wellness Influencers.. Insane Health advice!...
#    → 217 comments
#
#  ‘SkinnyTok’ Influencers Have Taken Over Health and Wellness ...
#    → 220 comments
#
#  TREAT YOUR BODY LIKE A TEMPLE: Tips on eating healthy, worko...
#    → 255 comments
#
#  STOP LISTENING TO WELLNESS INFLUENCERS OR AFFILIATE MARKETER...
#    → 207 comments
#
#  INSANE Wellness Influencers.. *Raw Diet, &quot;Demonic Food&...
#    → 217 comments
#
#  The Rise of India&#39;s Fitness Influencer Revolution...
#    → 156 comments
#
#  Dying Teen Listened to a Wellness Influencer Over Science | ...
#    → 155 comments
#
#  TikTok CARNIVORES are CRAZY...
#    → 207 comments
#
#  Food Theory: Liver King, The RAW Truth! (Carnivore Diet)...
#    → 252 comments
#
#  I Tried The Diet For Optimal Human Performance...
#    → 238 comments
#
#  I tried the Carnivore Diet for a week......
#    → 239 comments
#
#  TikTok Carnivores Are Insane...
#    → 240 comments
#
#  The Worst TikTok Carnivore Yet...
#    → 271 comments
#
#  Dr. Berg Goes Carnivore for 2 Weeks...
#    → 222 comments
#
#  Give Me 8 Minutes. I&#39;ll Save You 25 Years Of Carnivore M...
#    → 216 comments
#
#  Carnivore Diet - I AM STOPPING (202 Days In)- My Last Meal...
#    → 230 comments
#
#  TikTok Carnivores Are Getting Worse...
#    → 243 comments
#
#  Carnivore Diet: 47 BEGINNER TIPS For Success...
#    → 218 comments
#
#  Extreme diets and health trends people are swearing by | 60 ...
#    → 223 comments
#
#  Why I Quit Carnivore...
#    → 207 comments
#
#  EVERYONE Has Quit Carnivore! Doctor Explains...
#    → 208 comments
#
#  I’ve Only Been Eating Meat For The Past 8 Years | @drjoshaxe...
#    → 217 comments
#
#  Woman on Carnivore Diet | Kendahl Landreth...
#    → 247 comments
#
#  4 Carnivore Experts: The Ultimate Carnivore Diet For Women 2...
#    → 247 comments
#
# =====================================
# Dataset saved!
# Total videos: 30
# Total comments: 6626
# =====================================

# %% [markdown]
# ## 2. Data Preprocessing and Exploration

# %% [markdown]
# ### 2.1 Loading Dataset

# %%
# Open the original doctor/mental health dataset. 
# The initial collection of YouTube videos and comments is already included in this file.
with open("mental_health_dataset.json", "r", encoding="utf-8") as f:
    data1 = json.load(f)

# Open the updated influencer dataset.
# The extra videos and comments gathered independently are included in this file.
with open("influencer_dataset.json", "r", encoding="utf-8") as f:
    data2 = json.load(f)

# Gather every video ID from the original dataset. 
# Since videoId uniquely identifies every YouTube video, we use it.
existing_ids = {v["videoId"] for v in data1["videos"]}

#In order to avoid counting the same video and its comments again, only the influencer videos that weren't already in the 
#original dataset should be kept.
new_videos   = [v for v in data2["videos"] if v["videoId"] not in existing_ids]

# Merge the new, non-duplicate videos with the original ones.
# Only new influencer videos are included to the final dataset, which retains all original videos.
combined = {"videos": data1["videos"] + new_videos}

# Save the combined dataset back into the primary mental health dataset file. 
# This adds content about doctors and influencers to the file.
with open("mental_health_dataset.json", "w", encoding="utf-8") as f:
    json.dump(combined, f, ensure_ascii=False, indent=2)

print("=====================================")
print(" Merged!")
print(f"Original videos  : {len(data1['videos'])}")
print(f"New videos added : {len(new_videos)}")
print(f"Total videos     : {len(combined['videos'])}")
print(f"Total comments   : {sum(len(v['comments']) for v in combined['videos'])}")
print("=====================================")
# Out:
# =====================================
#  Merged!
# Original videos  : 60
# New videos added : 29
# Total videos     : 89
# Total comments   : 19428
# =====================================

# %%
# To store all comment-level data, create an empty list.
# Each comment will eventually be a single row in the final DataFrame.
all_rows = []

# Iterate over every video in the merged dataset.
for video in combined["videos"]:
    # Loop through every comment inside the current video.
    for comment in video["comments"]:
        # Store both video information and comment information together.
        # This creates a structured row that is easier to analyse later.
        all_rows.append({
            "video_id":      video["videoId"],     # Unique ID of the YouTube video.
            "title":         video["title"],       # Title of the video where the comment was posted.
            "channel":       video["channelTitle"],  # Name of the YouTube channel that uploaded the video.
            "view_count":    video["viewCount"],     # Total number of views for the video.
            "like_count":    video["likeCount"],     # Total number of likes for the video.
            "comment":       comment["text"],        # Actual text content of the YouTube comment.
            "author":        comment["author"],      # Username of the person who posted the comment.
            "reply_to":      comment["reply_to"],    # Shows who the comment was replying to.
                                                     # If it is a main comment, this value will be None.
            "comment_likes": comment["likeCount"],   # Number of likes received by the comment itself.
            "published_at":  comment["publishedAt"]  # Date and time when the comment was posted.
        })


# Convert the list of dictionaries into a Pandas DataFrame.
# A DataFrame makes the dataset easier to clean, analyse, and visualise.
df = pd.DataFrame(all_rows)

# Print a confirmation message to show the DataFrame was created successfully.
print(f" DataFrame rebuilt!")

# Print the total number of comments collected in the dataset.
print(f"Total comments: {len(df)}")
# Out:
#  DataFrame rebuilt!
# Total comments: 19428

# %%
# opening the saved dataset file in read mode
with open("mental_health_dataset.json", "r", encoding="utf-8") as f:
    # load the JSON data from the file into a Python dictionary
    data = json.load(f)
# extract the list of videos from the dataset
videos = data["videos"]
# print how many videos were collected
print("Total videos:", len(videos))
# Out:
# Total videos: 89

# %%
# create an empty list to store all comments from all videos
all_comments = []
# loop through each video in dataset.
for video in videos:
    # loop through each comment inside the current video
    for comment in video["comments"]:
        # extract the comment text and add it to the list.
        all_comments.append(comment["text"])
# print the total number of comments collected
print("Total comments:", len(all_comments))
# Out:
# Total comments: 19428

# %%
# create an empty list to store structured data
all_rows = []

# loop through each video in the dataset
for video in videos:
    # loop through each comment of the current video
    for comment in video["comments"]:
        all_rows.append({
            # video information
            "video_id":      video["videoId"],
            "title":         video["title"],
            "channel":       video["channelTitle"],  # for labelling
            "view_count":    video["viewCount"],
            "like_count":    video["likeCount"],

            # comment information
            "comment":       comment["text"],         # comment text
            "author":        comment["author"],        # for network nodes
            "reply_to":      comment["reply_to"],      # for network edges
            "comment_likes": comment["likeCount"],
            "published_at":  comment["publishedAt"]
        })

# convert to dataframe
df = pd.DataFrame(all_rows)

# print summary
print("Total comments:", len(df))
print("Columns:", df.columns.tolist())
df.head()
# Out:
# Total comments: 19428
# Columns: ['video_id', 'title', 'channel', 'view_count', 'like_count', 'comment', 'author', 'reply_to', 'comment_likes', 'published_at']
#       video_id                                       title      channel  \
# 0  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 1  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 2  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 3  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 4  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
#
#    view_count  like_count                                            comment  \
# 0    14264441      293869  Y'know what makes a surprisingly great comfort...
# 1    14264441      293869  4:07 this is witchcraft. this is my thing 😭 TH...
# 2    14264441      293869  I used to love me some codeine in my cough syr...
# 3    14264441      293869  1:35 why would we want evidence from where you...
# 4    14264441      293869                       Stop at a random moment 1:56
#
#                     author reply_to  comment_likes          published_at
# 0  @timdaferretmailman7297     None              1  2026-05-20T22:42:46Z
# 1      @TheZootedPriestess     None              0  2026-05-18T23:13:59Z
# 2        @robertvargas2324     None              0  2026-05-16T08:50:09Z
# 3        @elijahpolakoffTV     None              1  2026-05-11T22:18:02Z
# 4         @BLUEBERRY33-c2j     None              0  2026-05-10T03:26:53Z

# %% [markdown]
# ### 2.2 Data Cleaning

# %%
def clean_comment(text):
    # convert text to lowercase for consistency
    text = str(text).lower()
    
    # remove any URLs present in the text
    text = re.sub(r"http\S+", "", text)
    
    # remove emojis and non english characters
    text = re.sub(r"[^\x00-\x7F]+", "", text)
    
    # step to ensure only standard text remains
    text = text.encode("ascii", "ignore").decode()
    
    # keep only letters and spaces
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    
    # remove extra spaces and clean formatting
    text = re.sub(r"\s+", " ", text).strip()
    
    return text

# %%
# check what columns you actually have
print(df.columns.tolist())
print(df.shape)
print(df.head(3))
# Out:
# ['video_id', 'title', 'channel', 'view_count', 'like_count', 'comment', 'author', 'reply_to', 'comment_likes', 'published_at']
# (19428, 10)
#       video_id                                       title      channel  \
# 0  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 1  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 2  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
#
#    view_count  like_count                                            comment  \
# 0    14264441      293869  Y'know what makes a surprisingly great comfort...
# 1    14264441      293869  4:07 this is witchcraft. this is my thing 😭 TH...
# 2    14264441      293869  I used to love me some codeine in my cough syr...
#
#                     author reply_to  comment_likes          published_at
# 0  @timdaferretmailman7297     None              1  2026-05-20T22:42:46Z
# 1      @TheZootedPriestess     None              0  2026-05-18T23:13:59Z
# 2        @robertvargas2324     None              0  2026-05-16T08:50:09Z

# %%
print("\nMissing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# video_id             0
# title                0
# channel              0
# view_count           0
# like_count           0
# comment              0
# author               0
# reply_to         17247
# comment_likes        0
# published_at         0
# dtype: int64

# %%
# apply cleaning function to all comments correct column name
df["clean_comment"] = df["comment"].apply(clean_comment)

# clean video titles as well correct column name
df["clean_title"] = df["title"].apply(clean_comment)

# %%
# store count before cleaning for comparison
before_count = len(df)

# %%
# remove empty comments
df = df[df["clean_comment"].str.strip() != ""]

# %%
# remove very short comments
df = df[df["clean_comment"].str.len() > 3]

# %%
# keep only comments that contain text
df = df[df["clean_comment"].str.contains(r"[a-zA-Z]", regex=True)]

# %%
# count non-english comments
non_english_count = df[~df["clean_comment"].apply(lambda x: str(x).isascii())].shape[0]
print("Non-English comments:", non_english_count)
# Out:
# Non-English comments: 0

# %%
# count english comments
english_count = df[df["clean_comment"].apply(lambda x: str(x).isascii())].shape[0]
print("English comments:", english_count)
# Out:
# English comments: 18918

# %%
duplicates = df.duplicated(subset=["clean_comment"]).sum()
print("Duplicate comments:", duplicates)
# Out:
# Duplicate comments: 332

# %%
# keep only english comments
df = df[df["clean_comment"].apply(lambda x: str(x).isascii())]

# %%
# remove duplicate comments
df = df.drop_duplicates(subset=["comment"])

# %%
# after count
after_count = len(df)

# %%
print("\n=====================================")
print("Cleaning Complete!")
print(f"Before cleaning : {before_count}")
print(f"After cleaning  : {after_count}")
print(f"Removed         : {before_count - after_count}")
print(f"English comments: {english_count}")
print(f"Non-English     : {non_english_count}")
print("=====================================")

# preview
df.head()
# Out:
# =====================================
# Cleaning Complete!
# Before cleaning : 19428
# After cleaning  : 18780
# Removed         : 648
# English comments: 18918
# Non-English     : 0
# =====================================
#       video_id                                       title      channel  \
# 0  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 1  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 2  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 3  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 4  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
#
#    view_count  like_count                                            comment  \
# 0    14264441      293869  Y'know what makes a surprisingly great comfort...
# 1    14264441      293869  4:07 this is witchcraft. this is my thing 😭 TH...
# 2    14264441      293869  I used to love me some codeine in my cough syr...
# 3    14264441      293869  1:35 why would we want evidence from where you...
# 4    14264441      293869                       Stop at a random moment 1:56
#
#                     author reply_to  comment_likes          published_at  \
# 0  @timdaferretmailman7297     None              1  2026-05-20T22:42:46Z
# 1      @TheZootedPriestess     None              0  2026-05-18T23:13:59Z
# 2        @robertvargas2324     None              0  2026-05-16T08:50:09Z
# 3        @elijahpolakoffTV     None              1  2026-05-11T22:18:02Z
# 4         @BLUEBERRY33-c2j     None              0  2026-05-10T03:26:53Z
#
#                                        clean_comment  \
# 0  yknow what makes a surprisingly great comfort ...
# 1  this is witchcraft this is my thing this is a ...
# 2  i used to love me some codeine in my cough syr...
# 3  why would we want evidence from where your mom...
# 4                            stop at a random moment
#
#                                  clean_title
# 0  doctor factchecks tiktok nutrition advice
# 1  doctor factchecks tiktok nutrition advice
# 2  doctor factchecks tiktok nutrition advice
# 3  doctor factchecks tiktok nutrition advice
# 4  doctor factchecks tiktok nutrition advice

# %% [markdown]
# ### 2.3 Labelling

# %%
#  Define Keywords

# keywords that indicate medical professional / doctor content
DOCTOR_KEYWORDS = [
    'doctor', 'dr.', 'dr ', 'physician', 'surgeon', 'md ',
    'debunk', 'fact check', 'fact-check', 'medical', 'nurse',
    'gynecologist', 'urologist', 'scientist', 'cardiologist',
    'dermatologist', 'obgyn', 'psychiatrist', 'therapist',
    'biomedical', 'healthcare', 'debunking', 'reacts'
]

# keywords that indicate influencer / misinformation content
INFLUENCER_KEYWORDS = [
    'influencer', 'guru', 'coach', 'carnivore', 'wellness',
    'detox', 'natural cure', 'raw milk', 'supplement',
    'biohack', 'holistic', 'tiktok', 'instagram', 'viral',
    'exposed', 'conspiracy', 'alternative', 'naturopath',
    'hidden truth', 'they dont want', 'secret'
]


# Label Function

def label_video(title, channel):
    # combine title and channel for better accuracy
    text = (str(title) + " " + str(channel)).lower()

    doctor_score     = sum(1 for kw in DOCTOR_KEYWORDS     if kw in text)
    influencer_score = sum(1 for kw in INFLUENCER_KEYWORDS if kw in text)

    if doctor_score > influencer_score:
        return "doctor"
    elif influencer_score > doctor_score:
        return "influencer"
    else:
        return "both"


#  Apply Labels

df["video_label"] = df.apply(
    lambda row: label_video(row["title"], row["channel"]),
    axis=1
)


#  Print Distribution
print(" Labelling Complete!")
print("\nLabel Distribution (comments):")
print(df["video_label"].value_counts())
print("\n Label Distribution (unique videos):")
print(df.groupby("video_label")["video_id"].nunique())


# Visualise

# Count how many comments belong to each video category.
# value_counts() calculates the frequency of each label in the dataset.
label_counts = df["video_label"].value_counts()

# Create a new figure for the bar chart.
# figsize controls the size of the graph.
plt.figure(figsize=(7, 5))

# Create the bar chart.
# Each bar represents the number of comments for a specific video category.
bars = plt.bar(
    label_counts.index,
    label_counts.values,

    # Different colours are used to visually separate categories.
    color=["#2196F3", "#4CAF50", "#FF5722"],
    # Adds a black border around each bar for clarity.
    edgecolor="black",
    # Controls the width of each bar.
    width=0.5
)

# Add the exact count value on top of each bar.
# This makes the chart easier to read without estimating values visually.
for bar, count in zip(bars, label_counts.values):
    plt.text(
        # Places the text at the center of each bar.
        bar.get_x() + bar.get_width() / 2,
        # Places the text slightly above the top of the bar.
        bar.get_height() + 50,
        str(count),
        ha="center",
        fontweight="bold"
    )
# Add a title to explain what the graph shows.
plt.title("Comment Distribution by Video Label")
# Label the x-axis.
plt.xlabel("Video Label")
# Label the y-axis.
plt.ylabel("Number of Comments")
# Automatically adjusts spacing so labels do not overlap.
plt.tight_layout()
plt.show()


#  Save

df.to_csv("mental_health_cleaned.csv", index=False)
print("\nSaved with labels to mental_health_cleaned.csv")
print("\n Sample labelled data:")
print(df[["title", "channel", "video_label"]].drop_duplicates().head(10))
# Out:
#  Labelling Complete!
#
# Label Distribution (comments):
# doctor        10467
# influencer     4755
# both           3558
# Name: video_label, dtype: int64
#
#  Label Distribution (unique videos):
# video_label
# both          17
# doctor        50
# influencer    22
# Name: video_id, dtype: int64
# Saved with labels to mental_health_cleaned.csv
#
#  Sample labelled data:
#                                                   title  \
# 0            Doctor Fact-Checks TikTok Nutrition Advice
# 208                 Doctor Blocks Me For Correcting Him
# 419         Doctor Reacts To Scary TikTok Health Advice
# 627   TikTok &quot;Health&quot; Products You Should ...
# 848     Doctor Reacts To TERRIBLE TikTok Medical Advice
# 1061                    The Truth About Detox Smoothies
# 1265                      The Truth About Lemon Water 😲
# 1472        How “Health Gurus” Trick You ft Gary Brecka
# 1686      Debunking the worst haircare advice on TikTok
# 1899  Here&#39;s Why Doctor&#39;s NEVER Drink Detox Tea
#
#                         channel video_label
# 0                   Doctor Mike      doctor
# 208                 Doctor Mike      doctor
# 419                 Doctor Mike      doctor
# 627                 Doctor Mike        both
# 848                 Doctor Mike      doctor
# 1061                Doctor Mike        both
# 1265                Doctor Mike      doctor
# 1472                Doctor Mike        both
# 1686  Lab Muffin Beauty Science      doctor
# 1899                Doctor Mike        both

# %%
print(df.columns.tolist())
# Out:
# ['video_id', 'title', 'channel', 'view_count', 'like_count', 'comment', 'author', 'reply_to', 'comment_likes', 'published_at', 'clean_comment', 'clean_title', 'video_label']

# %% [markdown]
# ### 2.4 Tokenisation

# %%
class YouTubeProcessing:
    # create a class to handle text processing
    def __init__(self, tokeniser, lStopwords):
        # store the tokenizer
        self.tokeniser = tokeniser
        # store stopwords
        self.lStopwords = lStopwords

    # function to process and clean each piece of text
    def process(self, text):
        # convert text to lowercase for consistency
        text = text.lower()
        # split the text into individual words
        tokens = self.tokeniser.tokenize(text)
        # remove extra spaces around each token
        tokens = [tok.strip() for tok in tokens]
        # pattern to identify tokens containing numbers
        regexDigit = re.compile(r"^\d+\s|\s\d+\s|\s\d+$")
        # pattern to identify tokens starting with links
        regexHttp = re.compile(r"^http")
        return [tok for tok in tokens
                # remove common words like "the", "is" etc
                if tok not in self.lStopwords
                # remove tokens that contain numbers
                and regexDigit.match(tok) is None
                # remove tokens that are URLs
                and regexHttp.match(tok) is None]

# %%
# create tokeniser suitable for social media text
tokeniser = TweetTokenizer()

# combine english stopwords + punctuation + custom words
custom_stopwords = [
    "doctor", "doctors", "influencer", "influencers",
    "video", "youtube", "watch", "like", "comment",
    "said", "say", "says", "know", "think", "people",
    "one", "get", "got", "going", "would", "could",
    "really", "actually", "also", "even", "still",
    "tiktok", "instagram", "channel", "subscribe",
    "gt", "amp", "quot"                              # removes HTML artifacts
]

lStopwords = (
    stopwords.words('english') +
    list(string.punctuation) +
    custom_stopwords                                  # added for your project
)

# create processor object
processor = YouTubeProcessing(tokeniser, lStopwords)
print("Processor created")
# Out:
# Processor created

# %%
# apply processing function to each cleaned comment
df["tokens"] = df["clean_comment"].apply(lambda x: processor.process(str(x)))

# calculate token count per comment
df["token_count"] = df["tokens"].apply(len)

print("Tokenisation applied!")
print(f"Average tokens per comment: {df['token_count'].mean():.1f}")
print(f"Sample tokens: {df['tokens'].iloc[0]}")
# Out:
# Tokenisation applied!
# Average tokens per comment: 13.6
# Sample tokens: ['yknow', 'makes', 'surprisingly', 'great', 'comfort', 'bowl', 'imo', 'lettuce', 'fresh', 'tomatoes', 'refried', 'beans', 'melted', 'cheese', 'seasoned', 'rice', 'tried', 'mashed', 'together', 'almost', 'always', 'order', 'local', 'mexican', 'restaurant', 'lol']

# %%
# flatten all tokens into one list
all_tokens = [
    token
    for tokens in df["tokens"]
    for token in tokens
]

# get top 20 words
most_common = Counter(all_tokens).most_common(20)
words  = [w[0] for w in most_common]
counts = [w[1] for w in most_common]

# plot
plt.figure(figsize=(12, 5))
plt.bar(words, counts, color="steelblue", edgecolor="black")
plt.title("Top 20 Most Common Words in Health Comments")
plt.xlabel("Word")
plt.ylabel("Frequency")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# Loop through each video category separately.
# This allows us to compare the most common words used in different types of videos.
for label in ["doctor", "influencer", "both"]:
    # Create a list of all tokens belonging to the current label.
    # tokens = cleaned words from each comment
    # lbl = the category assigned to that comment/video
    label_tokens = [
        # Take each individual token (word)
        token
        # Loop through the tokenised comments and their labels together.
        for tokens, lbl in zip(df["tokens"], df["video_label"])
        # Keep only comments that belong to the current label.
        if lbl == label
        # Loop through every word inside each token list.
        for token in tokens
    ]
    print(f"\n Top 10 words in '{label}' videos:")
    print(Counter(label_tokens).most_common(10))
# Out:
#  Top 10 words in 'doctor' videos:
# [('dont', 987), ('im', 962), ('dr', 720), ('mike', 680), ('time', 524), ('much', 462), ('good', 432), ('water', 430), ('years', 404), ('love', 403)]
#
#  Top 10 words in 'influencer' videos:
# [('eat', 768), ('carnivore', 659), ('diet', 622), ('dont', 593), ('im', 583), ('meat', 526), ('eating', 459), ('milk', 346), ('good', 340), ('food', 336)]
#
#  Top 10 words in 'both' videos:
# [('de', 537), ('e', 440), ('que', 425), ('im', 321), ('dont', 301), ('diet', 285), ('carnivore', 231), ('dr', 202), ('good', 186), ('much', 181)]

# %%
# Save the cleaned DataFrame as a CSV file.
# index=False prevents Pandas from adding an extra row-number column to the file.
df.to_csv("mental_health_cleaned.csv", index=False)
# Print a confirmation message to show the file was saved successfully.
print("\nSaved with tokens to mental_health_cleaned.csv")

# Display the first 5 rows of the DataFrame.
# This helps quickly inspect whether the cleaned dataset looks correct.
df.head()
# Out:
# Saved with tokens to mental_health_cleaned.csv
#       video_id                                       title      channel  \
# 0  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 1  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 2  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 3  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
# 4  ep8ZMq3GLNA  Doctor Fact-Checks TikTok Nutrition Advice  Doctor Mike
#
#    view_count  like_count                                            comment  \
# 0    14264441      293869  Y'know what makes a surprisingly great comfort...
# 1    14264441      293869  4:07 this is witchcraft. this is my thing 😭 TH...
# 2    14264441      293869  I used to love me some codeine in my cough syr...
# 3    14264441      293869  1:35 why would we want evidence from where you...
# 4    14264441      293869                       Stop at a random moment 1:56
#
#                     author reply_to  comment_likes          published_at  \
# 0  @timdaferretmailman7297     None              1  2026-05-20T22:42:46Z
# 1      @TheZootedPriestess     None              0  2026-05-18T23:13:59Z
# 2        @robertvargas2324     None              0  2026-05-16T08:50:09Z
# 3        @elijahpolakoffTV     None              1  2026-05-11T22:18:02Z
# 4         @BLUEBERRY33-c2j     None              0  2026-05-10T03:26:53Z
#
#                                        clean_comment  \
# 0  yknow what makes a surprisingly great comfort ...
# 1  this is witchcraft this is my thing this is a ...
# 2  i used to love me some codeine in my cough syr...
# 3  why would we want evidence from where your mom...
# 4                            stop at a random moment
#
#                                  clean_title video_label  \
# 0  doctor factchecks tiktok nutrition advice      doctor
# 1  doctor factchecks tiktok nutrition advice      doctor
# 2  doctor factchecks tiktok nutrition advice      doctor
# 3  doctor factchecks tiktok nutrition advice      doctor
# 4  doctor factchecks tiktok nutrition advice      doctor
#
#                                               tokens  token_count
# 0  [yknow, makes, surprisingly, great, comfort, b...           26
# 1         [witchcraft, thing, spell, medical, stuff]            5
# 2  [used, love, codeine, cough, syrup, especially...            8
# 3                        [want, evidence, mom, died]            4
# 4                             [stop, random, moment]            3

# %% [markdown]
# ### 2.5 Intial Exploration (EDA)

# %%
# Group the dataset by video ID.
# size() counts how many comments belong to each video.
comments_per_video = df.groupby("video_id").size()

# Display summary statistics for the number of comments per video.
# describe() provides useful information such as:
# - count  → total number of videos
# - mean   → average comments per video
# - std    → variation in comment counts
# - min    → lowest number of comments
# - max    → highest number of comments
# - quartiles (25%, 50%, 75%) → distribution of comment activity
print(comments_per_video.describe())
# Out:
# count     89.000000
# mean     211.011236
# std       26.383317
# min       99.000000
# 25%      201.000000
# 50%      212.000000
# 75%      221.000000
# max      291.000000
# dtype: float64

# %%
# Create a new figure for the histogram.
# figsize controls the width and height of the graph.
plt.figure(figsize=(8,5))

# Create a histogram to show the distribution of comment counts across videos.
# Each bar represents how many videos fall within a certain comment range
plt.hist(comments_per_video, bins=20, edgecolor="black")
plt.title("Number of Comments per Video")
plt.xlabel("Comments")
plt.ylabel("Frequency")
plt.show()

# %%
# Sort videos based on the number of comments in descending order.
# head(10) selects the top 10 most commented videos.
top_videos = comments_per_video.sort_values(ascending=False).head(10)

# Replace video IDs with actual video titles for better readability in the graph.
# groupby("video_id")["title"].first() gets the title linked to each video ID.
top_videos.index = df.groupby("video_id")["title"].first().loc[top_videos.index]

# Create a horizontal bar chart.
# Each bar represents one of the top 10 most commented videos.
plt.figure(figsize=(10,5))
top_videos.plot(kind="barh", color="skyblue", edgecolor="black")
plt.gca().invert_yaxis()
plt.title("Top 10 Videos by Comment Count")
plt.xlabel("Number of Comments")
plt.ylabel("Video Title")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Text Analysis

# %% [markdown]
# ### 3.1 Unigram Analysis

# %%
# Create an empty dictionary to store unigram results for each video category.
# A unigram means a single word.
unigram_results = {}

# Loop through each video label separately.
# This helps compare the language used across different categories.
for label in ["doctor", "influencer", "both"]:

    # Create an empty list to store all words for the current category.
    all_words = []

    # Loop through tokenised comments and their corresponding labels together.
    for tokens, lbl in zip(df["tokens"], df["video_label"]):
        # Keep only comments that belong to the current label.
        if lbl == label:
            # Add all words from the current comment into the list.
            all_words.extend(tokens)

    # Count how often each word appears in the selected category.
    word_freq = Counter(all_words)

    # Select the 10 most common words.
    top_words = word_freq.most_common(10)

    # Store the results in the dictionary for later use or analysis.
    unigram_results[label] = top_words
    
    print(f"\nTop words in {label} videos:")
    print(top_words)
# Out:
# Top words in doctor videos:
# [('dont', 987), ('im', 962), ('dr', 720), ('mike', 680), ('time', 524), ('much', 462), ('good', 432), ('water', 430), ('years', 404), ('love', 403)]
#
# Top words in influencer videos:
# [('eat', 768), ('carnivore', 659), ('diet', 622), ('dont', 593), ('im', 583), ('meat', 526), ('eating', 459), ('milk', 346), ('good', 340), ('food', 336)]
#
# Top words in both videos:
# [('de', 537), ('e', 440), ('que', 425), ('im', 321), ('dont', 301), ('diet', 285), ('carnivore', 231), ('dr', 202), ('good', 186), ('much', 181)]

# %%
# Visualise the most common words for each video category.
# This helps compare the language and discussion themes across different types of videos.

# Loop through each category and its top words.
for label, top_words in unigram_results.items():

    # Separate words and their frequencies into two lists.
    words = [w for w, c in top_words]
    counts = [c for w, c in top_words]

    # Reverse the lists so the highest frequency appears at the top of the chart.
    words.reverse()
    counts.reverse()

    # Create a new figure for the horizontal bar chart.
    plt.figure(figsize=(8,4))

    # Create the horizontal bar chart.
    # Each bar represents the frequency of a word in the selected category.
    plt.barh(words, counts, color="steelblue", edgecolor="black")
    
    plt.title(f"Top Words in {label.capitalize()} Videos")
    plt.xlabel("Frequency")
    plt.ylabel("Words")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.2 Bigram Analysis

# %%
# Create an empty dictionary to store bigram results for each category.
# A bigram is a pair of consecutive words that appear together.
bigram_results = {}

# Loop through each video category separately.
# This helps compare common word pairs across different types of videos.
for label in ["doctor", "influencer", "both"]:

    # Create an empty list to store all bigrams for the current category.
    bigrams = []

    # Loop through tokenised comments and their corresponding labels together.
    for tokens, lbl in zip(df["tokens"], df["video_label"]):
        # Keep only comments that belong to the current label.
        if lbl == label:
            # Loop through the token list and create pairs of consecutive words.
            for i in range(len(tokens) - 1):
                # Store each pair of words as a tuple.
                bigrams.append((tokens[i], tokens[i+1]))

    # Count how often each bigram appears.
    bigram_freq = Counter(bigrams)

    # Select the 10 most common bigrams.
    top_bigrams = bigram_freq.most_common(10)

    # Store the results for later analysis or visualisation.
    bigram_results[label] = top_bigrams
    
    print(f"\nTop bigrams in {label} videos:")
    print(top_bigrams)
# Out:
# Top bigrams in doctor videos:
# [(('dr', 'mike'), 326), (('birth', 'control'), 135), (('please', 'please'), 70), (('years', 'ago'), 67), (('every', 'time'), 57), (('lemon', 'water'), 46), (('olive', 'oil'), 43), (('carnivore', 'diet'), 43), (('dont', 'need'), 41), (('chest', 'compressions'), 41)]
#
# Top bigrams in influencer videos:
# [(('carnivore', 'diet'), 180), (('raw', 'milk'), 166), (('red', 'meat'), 65), (('dont', 'eat'), 59), (('raw', 'meat'), 46), (('every', 'day'), 44), (('years', 'ago'), 43), (('lose', 'weight'), 39), (('eat', 'meat'), 36), (('dont', 'need'), 35)]
#
# Top bigrams in both videos:
# [(('dr', 'mike'), 73), (('carnivore', 'diet'), 70), (('tongkat', 'ali'), 42), (('dieta', 'carnvora'), 39), (('snake', 'oil'), 28), (('detox', 'tea'), 28), (('big', 'pharma'), 27), (('god', 'bless'), 23), (('every', 'day'), 20), (('blood', 'pressure'), 20)]

# %%
# Visualise the most common bigrams for each video category.
# This helps identify common word pair patterns and discussion themes.

# Loop through each category and its top bigrams.
for label, top_bigrams in bigram_results.items():

    # Combine each word pair into a readable phrase.
    # Example: ("mental", "health") → "mental health"
    phrases = [f"{w1} {w2}" for (w1, w2), c in top_bigrams]
    # Extract the frequency count for each bigram.
    counts = [c for (w1, w2), c in top_bigrams]

    # Reverse the lists so the most frequent phrase appears at the top.
    phrases.reverse()
    counts.reverse()

    # Create a new figure for the chart.
    plt.figure(figsize=(8,4))

    # Create a horizontal bar chart.
    # Each bar represents how often a phrase appears.
    plt.barh(phrases, counts, color="orange", edgecolor="black")
    
    plt.title(f"Top Bigrams in {label.capitalize()} Videos")
    plt.xlabel("Frequency")
    plt.ylabel("Phrases")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.3 Sentiment Analysis

# %%
# download once
nltk.download('vader_lexicon')

# Create an instance of the sentiment analyser.
# This object will later calculate sentiment scores for each comment.
sia = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each cleaned comment.
# polarity_scores() returns multiple sentiment values:
# - positive
# - negative
# - neutral
# - compound
#
# We use the compound score because it gives an overall sentiment score
# ranging from -1 (very negative) to +1 (very positive).
df["sentiment_score"] = df["clean_comment"].apply(
    lambda x: sia.polarity_scores(x)["compound"]
)

# Create a function to convert numerical sentiment scores into labels.
# This makes the results easier to interpret.
def get_sentiment_label(score):

    # Positive score means the comment expresses positive sentiment.
    if score > 0:
        return "positive"

    # Negative score means the comment expresses negative sentiment
    elif score < 0:
        return "negative"

    # A score of 0 is treated as neutral sentiment.
    else:
        return "neutral"

df["sentiment"] = df["sentiment_score"].apply(get_sentiment_label)

print(df[["clean_comment", "sentiment_score", "sentiment"]].head())
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/sreelakshmi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                        clean_comment  sentiment_score  \
# 0  yknow what makes a surprisingly great comfort ...           0.9169
# 1  this is witchcraft this is my thing this is a ...           0.0000
# 2  i used to love me some codeine in my cough syr...           0.8428
# 3  why would we want evidence from where your mom...          -0.5106
# 4                            stop at a random moment          -0.2960
#
#   sentiment
# 0  positive
# 1   neutral
# 2  positive
# 3  negative
# 4  negative

# %%
# Count how many comments belong to each sentiment category.
# value_counts() calculates the frequency of positive, negative, and neutral comments.
sentiment_counts = df["sentiment"].value_counts()

# Create a new figure for the bar chart.
# figsize controls the width and height of the graph.
plt.figure(figsize=(6,4))

# Create a bar chart to visualise the sentiment distribution.
# Each bar represents the number of comments in a sentiment category.
sentiment_counts.plot(kind="bar", color=["green", "red", "gray"], edgecolor="black")

plt.title("Overall Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print(sentiment_counts)
# Out:
# positive    7773
# negative    5513
# neutral     5494
# Name: sentiment, dtype: int64

# %%
# Group the dataset by video category.
# Then calculate the average sentiment score for each category.
# mean() helps measure the overall emotional tone of comments in each group.
sentiment_by_label = df.groupby("video_label")["sentiment_score"].mean()

# Display the average sentiment score for each video category.
# Higher positive values indicate more positive audience reactions,
# while lower negative values indicate more negative sentiment.
print("\nAverage Sentiment Score by Label:")
print(sentiment_by_label)
# Out:
# Average Sentiment Score by Label:
# video_label
# both          0.101024
# doctor        0.068433
# influencer    0.077460
# Name: sentiment_score, dtype: float64

# %%
# Create a bar chart to compare the average sentiment score
# across different video categories.
sentiment_by_label.plot(kind="bar", color="purple", edgecolor="black")

# Add a title describing the purpose of the graph.
# This chart compares audience sentiment between doctor and influencer videos.
plt.title("Average Sentiment: Doctor vs Influencer")
plt.xlabel("Video Label")
plt.ylabel("Average Sentiment Score")

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.4 Topic Analysis

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create a CountVectorizer object.
# This will prepare the text data for topic modelling and machine learning.
vectorizer = CountVectorizer(
    # Ignores words that appear in more than 90% of comments.
    # These words are usually too common to provide meaningful insights.
    max_df=0.9,

    # Keeps only words that appear at least 10 times in the dataset.
    # This removes very rare words that may add noise.
    min_df=10,

    # Automatically removes common English stopwords
    # such as "the", "is", and "and".
    stop_words='english'
)

# Convert the cleaned comments into a document-term matrix.
# Rows represent comments.
# Columns represent words.
# Values represent how often each word appears in each comment.
X = vectorizer.fit_transform(df["clean_comment"])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Create the LDA model.
lda = LatentDirichletAllocation(

    # Defines the number of topics the model should discover.
    # Here, the model will group comments into 5 different topics.
    n_components=5,   # number of topics

    # Sets a fixed random seed so results remain consistent each time the code runs.
    random_state=42
)

# Train the LDA model using the document-term matrix created earlier.
# The model analyses word patterns and learns which words frequently appear together.
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
# Get all feature names (words) learned by the CountVectorizer.
# These are the words used by the LDA model during topic modelling.
words = vectorizer.get_feature_names()

# Loop through each discovered topic.
# enumerate() gives:
# - i      → topic number
# - topic  → importance scores of words within that topic
for i, topic in enumerate(lda.components_):
    # topic.argsort() sorts words based on their importance scores.
    # [-10:] selects the 10 most important words for the topic.
    # The list comprehension converts word indexes into actual words.
    print(f"\nTopic {i}:")
    print([words[i] for i in topic.argsort()[-10:]])
# Out:
# Topic 0:
# ['think', 'hes', 'know', 'im', 'dont', 'doctor', 'just', 'like', 'mike', 'dr']
#
# Topic 1:
# ['great', 'good', 'diet', 'just', 'thank', 'carnivore', 'video', 'love', 'like', 'eat']
#
# Topic 2:
# ['lemon', 'vegan', 'food', 'drink', 'hair', 'raw', 'milk', 'meat', 'que', 'water']
#
# Topic 3:
# ['got', 'think', 'doctors', 'doctor', 'time', 'know', 'dont', 'like', 'just', 'people']
#
# Topic 4:
# ['eating', 'ive', 'years', 'day', 'like', 'just', 'body', 'carnivore', 'diet', 'im']

# %%
# Loop through each video category separately.
# This allows topic modelling to be performed independently
# for doctor videos and influencer videos.
for label in ["doctor", "influencer"]:

    # Create a subset of the dataset containing only the selected category.
    subset = df[df["video_label"] == label]

    # Create a CountVectorizer object to convert text into numerical form.
    vectorizer = CountVectorizer(max_df=0.9, min_df=10, stop_words='english')

    # Convert cleaned comments into a document-term matrix.
    # This matrix is required for topic modelling.
    X = vectorizer.fit_transform(subset["clean_comment"])

    # Create the LDA topic modelling algorithm.
    lda = LatentDirichletAllocation(n_components=3, random_state=42)
    # Train the LDA model on the current category's comments.
    lda.fit(X)

    # Get the list of words learned by the vectorizer.
    words = vectorizer.get_feature_names()
    
    print(f"\nTopics in {label} videos:")

    # Loop through each discovered topic.
    for i, topic in enumerate(lda.components_):
        print(f"\nTopic {i}:")
        print([words[i] for i in topic.argsort()[-10:]])
# Out:
# Topics in doctor videos:
#
# Topic 0:
# ['really', 'thats', 'think', 'doctor', 'know', 'like', 'people', 'im', 'dont', 'just']
#
# Topic 1:
# ['control', 'house', 'guy', 'video', 'im', 'like', 'doctor', 'love', 'dr', 'mike']
#
# Topic 2:
# ['years', 'carnivore', 'just', 'got', 'time', 'day', 'eat', 'did', 'water', 'like']
#
# Topics in influencer videos:
#
# Topic 0:
# ['thanks', 'videos', 'bhai', 'liver', 'thank', 'hai', 'like', 'love', 'dr', 'video']
#
# Topic 1:
# ['weight', 'just', 'eating', 'day', 'like', 'fat', 'diet', 'eat', 'im', 'carnivore']
#
# Topic 2:
# ['carnivore', 'raw', 'good', 'diet', 'eat', 'like', 'meat', 'dont', 'people', 'just']

# %%
# Get all feature names (words) learned by the CountVectorizer.
# These words are used by the LDA model to build topics.
words = vectorizer.get_feature_names()

# Loop through each topic discovered by the LDA model.
# enumerate() provides:
# - i      → topic number
# - topic  → word importance scores for that topic
for i, topic in enumerate(lda.components_):

    # Sort word indexes based on their importance scores
    # and select the 10 most important words for the topic.
    top_indices = topic.argsort()[-10:]
    top_words = [words[j] for j in top_indices]
    top_weights = [topic[j] for j in top_indices]
    
    # reverse for better display
    top_words.reverse()
    top_weights.reverse()
    
    plt.figure(figsize=(8,4))
    plt.barh(top_words, top_weights, color="purple", edgecolor="black")
    
    plt.title(f"Top Words in Topic {i}")
    plt.xlabel("Weight")
    plt.ylabel("Words")
    
    plt.tight_layout()
    plt.show()

# %%
# Transform the document-term matrix using the trained LDA model.
# This calculates the probability distribution of topics for each comment.
# Each row represents a comment,
# and each column represents the probability of belonging to a topic.

topic_distribution = lda.transform(X)

# Identify the dominant topic for each comment.
# argmax() selects the topic with the highest probability score.
topic_counts = np.argmax(topic_distribution, axis=1)

# Count how many comments belong to each dominant topic.
# bincount() calculates the frequency of each topic number.
topic_counts = np.bincount(topic_counts)

plt.figure(figsize=(6,4))
plt.bar(range(len(topic_counts)), topic_counts, color="green", edgecolor="black")

plt.title("Topic Distribution")
plt.xlabel("Topic Number")
plt.ylabel("Number of Comments")

plt.tight_layout()
plt.show()

# %%
# Create a dictionary containing words and their importance scores.
# lda.components_[0] represents the first topic discovered by the LDA model.
# Higher scores mean the word is more important within that topic.
topic_words = dict([(words[i], lda.components_[0][i]) for i in range(len(words))])

# Create the WordCloud object.
# background_color="white" gives the word cloud a white background.
wc = WordCloud(background_color="white").generate_from_frequencies(topic_words)

# Display the generated word cloud image.
# interpolation="bilinear" smooths the visual appearance.
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Topic WordCloud")
plt.show()

# %% [markdown]
# ## 4. Network Analysis

# %%
# Create a directed graph using NetworkX.
# A directed graph stores relationships where direction matters.
# In this case:
# author  →  person being replied to
G = nx.DiGraph()

# Loop through every row in the dataset.
# Each row represents one comment.
for _, row in df.iterrows():

    # Check whether the comment is a reply to another user.
    # pd.notna() ensures the value is not missing.
    if pd.notna(row["reply_to"]):
        # Add a directed connection between users.
        # This creates an edge from:
        # commenter → user being replied to
        #
        # Example:
        # "User A replied to User B"
        # creates:
        # User A → User B
        G.add_edge(row["author"], row["reply_to"])

# convert to undirected for stable centrality calculations
G_co = G.to_undirected()

# %% [markdown]
# ### 4.1 Centrality

# %%
#  Degree centrality 
# Proportion of users a node interacts with
# High degree = user receives/replies to many comments (high engagement)
degree_cent = nx.degree_centrality(G_co)

# %%
# Weighted degree (strength) 
# Since your graph is unweighted, this is same as degree
strength = dict(G_co.degree())

# %%
# Betweenness centrality  
# Measures if a user connects different parts of discussion
# Using subgraph to avoid errors and focus on active users
top_nodes = sorted(G_co.degree, key=lambda x: x[1], reverse=True)[:50]
top_nodes = [n[0] for n in top_nodes]

subgraph = G_co.subgraph(top_nodes)

# manual betweenness (stable for your system)
betweenness_cent = dict.fromkeys(subgraph.nodes(), 0.0)

for source in subgraph.nodes():
    paths = nx.single_source_shortest_path(subgraph, source)
    for target, path in paths.items():
        for node in path[1:-1]:
            betweenness_cent[node] += 1

# normalize
n = len(subgraph.nodes())
if n > 2:
    for node in betweenness_cent:
        betweenness_cent[node] /= ((n - 1) * (n - 2))

# %%
# Eigenvector centrality 
# High value = connected to influential users
try:
    eigen_cent = nx.eigenvector_centrality(G_co, max_iter=1000)
except:
    print("Eigenvector did not converge, using degree centrality")
    eigen_cent = degree_cent

# %%
#  Clustering coefficient 
# Measures how tightly users interact in groups
clustering = nx.clustering(G_co)

# %%
# Compile node feature table 
node_features = pd.DataFrame({
    'user_id': list(G_co.nodes()),
    'degree': [G_co.degree(n) for n in G_co.nodes()],
    'degree_centrality': [degree_cent[n] for n in G_co.nodes()],
    'strength': [strength[n] for n in G_co.nodes()],
    'betweenness_centrality': [betweenness_cent.get(n, 0) for n in G_co.nodes()],
    'eigenvector_centrality': [eigen_cent[n] for n in G_co.nodes()],
    'clustering_coefficient': [clustering[n] for n in G_co.nodes()],
})

# preview
print(node_features.head())
# Out:
#                   user_id  degree  degree_centrality  strength  \
# 0              @BODHI-h6j       2           0.000902         2
# 1  @MichaelMartinez-ds1vd       1           0.000451         1
# 2              @john_d_91       4           0.001803         4
# 3     @MarshEllo189roblox       1           0.000451         1
# 4         @SolidState5150       1           0.000451         1
#
#    betweenness_centrality  eigenvector_centrality  clustering_coefficient
# 0                     0.0            1.200040e-20                     0.0
# 1                     0.0            2.301089e-15                     0.0
# 2                     0.0            4.602178e-15                     0.0
# 3                     0.0            1.200040e-20                     0.0
# 4                     0.0            1.200040e-20                     0.0

# %%
print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())
# Out:
# Nodes: 2219
# Edges: 1826

# %%
# Calculate degree centrality for each user in the graph.
# Degree centrality measures how connected a user is within the network.
#
# A higher score means the user interacts with many others
# or receives many replies from others.
degree_centrality = nx.degree_centrality(G)

# Sort users based on their centrality scores in descending order.
# reverse=True ensures the highest scores appear first.
#
# [:10] selects the top 10 most connected users.
top_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:10]

print("Top users by Degree Centrality:")
for user, score in top_degree:
    print(user, score)
# Out:
# Top users by Degree Centrality:
# @DoctorMike 0.023895401262398554
# @ashleyhetherington_ 0.011722272317403064
# @lirilsoni 0.011722272317403064
# @drjayeshsharma 0.009467989179440937
# @mephistomadeadeal 0.008115419296663661
# @Vegan_Vlogs 0.007664562669071235
# @Homesteadhow 0.005410279531109107
# @foreignuser_ 0.004508566275924256
# @waspwrap1235 0.0040577096483318306
# @Charlesco 0.0040577096483318306

# %%
#Visualising the Degree Distribution of the User Interaction Network
degrees = [d for _, d in G.degree()]
plt.figure(figsize=(8,4))
plt.hist(degrees, bins=30, color="#4fc3f7", edgecolor="black")
plt.xlabel("Degree")
plt.ylabel("Number of Users")
plt.title("Degree Distribution of User Interaction Network")
plt.savefig("degree_distribution.png", dpi=150)

# %%
# top 10 users by degree
top_users = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:10]

users = [u for u, _ in top_users]
scores = [s for _, s in top_users]

# reverse for better display
users.reverse()
scores.reverse()

plt.figure(figsize=(8,4))
plt.barh(users, scores)

plt.title("Top Influential Users (Degree Centrality)")
plt.xlabel("Centrality Score")
plt.ylabel("User")

plt.tight_layout()
plt.show()

# %%
# Remove self-loops
G_clean = G.copy()
G_clean.remove_edges_from(nx.selfloop_edges(G_clean))

# Get top 20 hubs
top_hubs = sorted(G_clean.degree(), key=lambda x: x[1], reverse=True)[:20]
top_hubs = [n for n, _ in top_hubs]

# Also include their neighbours (spokes)
neighbours = set()
for hub in top_hubs:
    neighbours.update(G_clean.predecessors(hub))
    neighbours.update(G_clean.successors(hub))

all_nodes = list(set(top_hubs) | neighbours)
print(f"Total nodes in subgraph: {len(all_nodes)}")

# Convert to real DiGraph
subgraph = nx.DiGraph(G_clean.subgraph(all_nodes))
print(f"Edges in subgraph: {subgraph.number_of_edges()}")

# Colour nodes — hubs larger and coloured, spokes small gray
node_colors = []
node_sizes = []
for n in subgraph.nodes():
    if n in top_hubs:
        label = df[df["author"] == n]["video_label"].mode()
        if len(label) > 0:
            if label[0] == "doctor":
                node_colors.append("skyblue")
            elif label[0] == "influencer":
                node_colors.append("salmon")
            else:
                node_colors.append("lightgreen")
        else:
            node_colors.append("lightgray")
        node_sizes.append(subgraph.degree(n) * 200 + 200)
    else:
        node_colors.append("lightgray")
        node_sizes.append(30)

pos = nx.kamada_kawai_layout(subgraph)

plt.figure(figsize=(14, 12))
nx.draw(
    subgraph, pos,
    node_size=node_sizes,
    node_color=node_colors,
    edge_color="gray",
    alpha=0.7,
    arrows=True,
    arrowsize=8,
    with_labels=False
)

legend = [
    Patch(color="skyblue", label="Doctor"),
    Patch(color="salmon", label="Influencer"),
    Patch(color="lightgreen", label="Both"),
    Patch(color="lightgray", label="Other users")
]
plt.legend(handles=legend, loc="upper left")
plt.title("User Interaction Network (Top 20 Hubs + Their Connections)")
plt.show()

# %% [markdown]
# ### 4.2 Community Detection

# %%
# Community Detection (Louvain) 
# Convert to undirected for Louvain
import community as community_louvain
G_undirected = G.to_undirected()
partition = community_louvain.best_partition(G_undirected)

# Count communities
community_counts = Counter(partition.values())
print(f"\nTotal communities found: {len(community_counts)}")
print("\nCommunity sizes:")
for comm_id, size in sorted(community_counts.items(), key=lambda x: -x[1]):
    print(f"  Community {comm_id}: {size} users")
# Out:
# Total communities found: 690
#
# Community sizes:
#   Community 206: 56 users
#   Community 124: 53 users
#   Community 513: 36 users
#   Community 168: 31 users
#   Community 498: 31 users
#   Community 70: 26 users
#   Community 174: 23 users
#   Community 179: 21 users
#   Community 672: 19 users
#   Community 575: 18 users
#   Community 416: 17 users
#   Community 20: 16 users
#   Community 601: 16 users
#   Community 198: 14 users
#   Community 490: 14 users
#   Community 53: 13 users
#   Community 439: 13 users
#   Community 637: 13 users
#   Community 142: 12 users
#   Community 624: 12 users
#   Community 110: 11 users
#   Community 681: 11 users
#   Community 48: 10 users
#   Community 54: 10 users
#   Community 557: 10 users
#   Community 675: 10 users
#   Community 18: 9 users
#   Community 202: 9 users
#   Community 652: 9 users
#   Community 26: 8 users
#   Community 87: 8 users
#   Community 120: 8 users
#   Community 588: 8 users
#   Community 19: 7 users
#   Community 55: 7 users
#   Community 98: 7 users
#   Community 128: 7 users
#   Community 217: 7 users
#   Community 231: 7 users
#   Community 491: 7 users
#   Community 594: 7 users
#   Community 60: 6 users
#   Community 61: 6 users
#   Community 81: 6 users
#   Community 105: 6 users
#   Community 157: 6 users
#   Community 177: 6 users
#   Community 209: 6 users
#   Community 248: 6 users
#   Community 260: 6 users
#   Community 287: 6 users
#   Community 291: 6 users
#   Community 364: 6 users
#   Community 411: 6 users
#   Community 482: 6 users
#   Community 494: 6 users
#   Community 524: 6 users
#   Community 529: 6 users
#   Community 530: 6 users
#   Community 546: 6 users
#   Community 550: 6 users
#   Community 558: 6 users
#   Community 584: 6 users
#   Community 641: 6 users
#   Community 50: 5 users
#   Community 62: 5 users
#   Community 63: 5 users
#   Community 67: 5 users
#   Community 118: 5 users
#   Community 139: 5 users
#   Community 155: 5 users
#   Community 178: 5 users
#   Community 203: 5 users
#   Community 205: 5 users
#   Community 220: 5 users
#   Community 286: 5 users
#   Community 340: 5 users
#   Community 433: 5 users
#   Community 476: 5 users
#   Community 500: 5 users
#   Community 526: 5 users
#   Community 531: 5 users
#   Community 532: 5 users
#   Community 548: 5 users
#   Community 552: 5 users
#   Community 560: 5 users
#   Community 567: 5 users
#   Community 616: 5 users
#   Community 618: 5 users
#   Community 626: 5 users
#   Community 645: 5 users
#   Community 648: 5 users
#   Community 677: 5 users
#   Community 685: 5 users
#   Community 21: 4 users
#   Community 36: 4 users
#   Community 41: 4 users
#   Community 78: 4 users
#   Community 89: 4 users
#   Community 97: 4 users
#   Community 117: 4 users
#   Community 135: 4 users
#   Community 160: 4 users
#   Community 166: 4 users
#   Community 173: 4 users
#   Community 204: 4 users
#   Community 222: 4 users
#   Community 264: 4 users
#   Community 266: 4 users
#   Community 274: 4 users
#   Community 275: 4 users
#   Community 310: 4 users
#   Community 315: 4 users
#   Community 320: 4 users
#   Community 342: 4 users
#   Community 345: 4 users
#   Community 346: 4 users
#   Community 362: 4 users
#   Community 385: 4 users
#   Community 396: 4 users
#   Community 426: 4 users
#   Community 432: 4 users
#   Community 441: 4 users
#   Community 442: 4 users
#   Community 458: 4 users
#   Community 465: 4 users
#   Community 506: 4 users
#   Community 507: 4 users
#   Community 516: 4 users
#   Community 527: 4 users
#   Community 538: 4 users
#   Community 539: 4 users
#   Community 543: 4 users
#   Community 555: 4 users
#   Community 570: 4 users
#   Community 579: 4 users
#   Community 582: 4 users
#   Community 593: 4 users
#   Community 600: 4 users
#   Community 603: 4 users
#   Community 638: 4 users
#   Community 668: 4 users
#   Community 669: 4 users
#   Community 676: 4 users
#   Community 132: 4 users
#   Community 1: 3 users
#   Community 9: 3 users
#   Community 12: 3 users
#   Community 16: 3 users
#   Community 37: 3 users
#   Community 47: 3 users
#   Community 56: 3 users
#   Community 90: 3 users
#   Community 96: 3 users
#   Community 100: 3 users
#   Community 104: 3 users
#   Community 107: 3 users
#   Community 108: 3 users
#   Community 109: 3 users
#   Community 111: 3 users
#   Community 115: 3 users
#   Community 121: 3 users
#   Community 126: 3 users
#   Community 127: 3 users
#   Community 130: 3 users
#   Community 140: 3 users
#   Community 144: 3 users
#   Community 146: 3 users
#   Community 158: 3 users
#   Community 171: 3 users
#   Community 201: 3 users
#   Community 213: 3 users
#   Community 219: 3 users
#   Community 227: 3 users
#   Community 250: 3 users
#   Community 251: 3 users
#   Community 269: 3 users
#   Community 277: 3 users
#   Community 283: 3 users
#   Community 305: 3 users
#   Community 313: 3 users
#   Community 319: 3 users
#   Community 334: 3 users
#   Community 339: 3 users
#   Community 348: 3 users
#   Community 355: 3 users
#   Community 358: 3 users
#   Community 360: 3 users
#   Community 377: 3 users
#   Community 378: 3 users
#   Community 387: 3 users
#   Community 397: 3 users
#   Community 401: 3 users
#   Community 402: 3 users
#   Community 410: 3 users
#   Community 420: 3 users
#   Community 438: 3 users
#   Community 443: 3 users
#   Community 451: 3 users
#   Community 456: 3 users
#   Community 461: 3 users
#   Community 464: 3 users
#   Community 467: 3 users
#   Community 472: 3 users
#   Community 474: 3 users
#   Community 495: 3 users
#   Community 499: 3 users
#   Community 502: 3 users
#   Community 505: 3 users
#   Community 508: 3 users
#   Community 528: 3 users
#   Community 535: 3 users
#   Community 542: 3 users
#   Community 545: 3 users
#   Community 561: 3 users
#   Community 589: 3 users
#   Community 592: 3 users
#   Community 597: 3 users
#   Community 598: 3 users
#   Community 608: 3 users
#   Community 610: 3 users
#   Community 614: 3 users
#   Community 631: 3 users
#   Community 639: 3 users
#   Community 643: 3 users
#   Community 649: 3 users
#   Community 655: 3 users
#   Community 663: 3 users
#   Community 670: 3 users
#   Community 678: 3 users
#   Community 679: 3 users
#   Community 684: 3 users
#   Community 687: 3 users
#   Community 122: 3 users
#   Community 2: 2 users
#   Community 3: 2 users
#   Community 4: 2 users
#   Community 6: 2 users
#   Community 7: 2 users
#   Community 8: 2 users
#   Community 10: 2 users
#   Community 11: 2 users
#   Community 13: 2 users
#   Community 14: 2 users
#   Community 15: 2 users
#   Community 22: 2 users
#   Community 23: 2 users
#   Community 24: 2 users
#   Community 25: 2 users
#   Community 27: 2 users
#   Community 28: 2 users
#   Community 29: 2 users
#   Community 31: 2 users
#   Community 32: 2 users
#   Community 33: 2 users
#   Community 34: 2 users
#   Community 35: 2 users
#   Community 38: 2 users
#   Community 39: 2 users
#   Community 40: 2 users
#   Community 42: 2 users
#   Community 43: 2 users
#   Community 44: 2 users
#   Community 45: 2 users
#   Community 46: 2 users
#   Community 49: 2 users
#   Community 51: 2 users
#   Community 52: 2 users
#   Community 57: 2 users
#   Community 58: 2 users
#   Community 59: 2 users
#   Community 64: 2 users
#   Community 66: 2 users
#   Community 68: 2 users
#   Community 69: 2 users
#   Community 71: 2 users
#   Community 73: 2 users
#   Community 74: 2 users
#   Community 75: 2 users
#   Community 76: 2 users
#   Community 77: 2 users
#   Community 79: 2 users
#   Community 80: 2 users
#   Community 82: 2 users
#   Community 83: 2 users
#   Community 84: 2 users
#   Community 85: 2 users
#   Community 86: 2 users
#   Community 91: 2 users
#   Community 92: 2 users
#   Community 93: 2 users
#   Community 94: 2 users
#   Community 95: 2 users
#   Community 99: 2 users
#   Community 101: 2 users
#   Community 102: 2 users
#   Community 103: 2 users
#   Community 106: 2 users
#   Community 112: 2 users
#   Community 113: 2 users
#   Community 114: 2 users
#   Community 116: 2 users
#   Community 123: 2 users
#   Community 125: 2 users
#   Community 129: 2 users
#   Community 131: 2 users
#   Community 134: 2 users
#   Community 136: 2 users
#   Community 137: 2 users
#   Community 138: 2 users
#   Community 141: 2 users
#   Community 143: 2 users
#   Community 145: 2 users
#   Community 147: 2 users
#   Community 148: 2 users
#   Community 150: 2 users
#   Community 151: 2 users
#   Community 152: 2 users
#   Community 153: 2 users
#   Community 154: 2 users
#   Community 156: 2 users
#   Community 159: 2 users
#   Community 161: 2 users
#   Community 163: 2 users
#   Community 164: 2 users
#   Community 165: 2 users
#   Community 167: 2 users
#   Community 170: 2 users
#   Community 172: 2 users
#   Community 175: 2 users
#   Community 176: 2 users
#   Community 180: 2 users
#   Community 181: 2 users
#   Community 182: 2 users
#   Community 183: 2 users
#   Community 184: 2 users
#   Community 185: 2 users
#   Community 186: 2 users
#   Community 187: 2 users
#   Community 188: 2 users
#   Community 189: 2 users
#   Community 190: 2 users
#   Community 191: 2 users
#   Community 192: 2 users
#   Community 193: 2 users
#   Community 194: 2 users
#   Community 195: 2 users
#   Community 196: 2 users
#   Community 197: 2 users
#   Community 199: 2 users
#   Community 200: 2 users
#   Community 207: 2 users
#   Community 208: 2 users
#   Community 210: 2 users
#   Community 211: 2 users
#   Community 212: 2 users
#   Community 218: 2 users
#   Community 221: 2 users
#   Community 223: 2 users
#   Community 225: 2 users
#   Community 228: 2 users
#   Community 229: 2 users
#   Community 230: 2 users
#   Community 232: 2 users
#   Community 234: 2 users
#   Community 235: 2 users
#   Community 236: 2 users
#   Community 237: 2 users
#   Community 238: 2 users
#   Community 239: 2 users
#   Community 240: 2 users
#   Community 241: 2 users
#   Community 242: 2 users
#   Community 243: 2 users
#   Community 244: 2 users
#   Community 245: 2 users
#   Community 246: 2 users
#   Community 247: 2 users
#   Community 249: 2 users
#   Community 255: 2 users
#   Community 256: 2 users
#   Community 257: 2 users
#   Community 259: 2 users
#   Community 262: 2 users
#   Community 263: 2 users
#   Community 265: 2 users
#   Community 267: 2 users
#   Community 270: 2 users
#   Community 271: 2 users
#   Community 272: 2 users
#   Community 273: 2 users
#   Community 276: 2 users
#   Community 278: 2 users
#   Community 279: 2 users
#   Community 280: 2 users
#   Community 281: 2 users
#   Community 282: 2 users
#   Community 285: 2 users
#   Community 289: 2 users
#   Community 292: 2 users
#   Community 296: 2 users
#   Community 298: 2 users
#   Community 299: 2 users
#   Community 300: 2 users
#   Community 301: 2 users
#   Community 306: 2 users
#   Community 308: 2 users
#   Community 309: 2 users
#   Community 311: 2 users
#   Community 312: 2 users
#   Community 314: 2 users
#   Community 316: 2 users
#   Community 318: 2 users
#   Community 322: 2 users
#   Community 323: 2 users
#   Community 324: 2 users
#   Community 325: 2 users
#   Community 327: 2 users
#   Community 328: 2 users
#   Community 331: 2 users
#   Community 333: 2 users
#   Community 335: 2 users
#   Community 336: 2 users
#   Community 337: 2 users
#   Community 338: 2 users
#   Community 341: 2 users
#   Community 344: 2 users
#   Community 347: 2 users
#   Community 353: 2 users
#   Community 354: 2 users
#   Community 356: 2 users
#   Community 357: 2 users
#   Community 359: 2 users
#   Community 363: 2 users
#   Community 365: 2 users
#   Community 366: 2 users
#   Community 367: 2 users
#   Community 369: 2 users
#   Community 373: 2 users
#   Community 374: 2 users
#   Community 376: 2 users
#   Community 379: 2 users
#   Community 380: 2 users
#   Community 381: 2 users
#   Community 382: 2 users
#   Community 383: 2 users
#   Community 384: 2 users
#   Community 386: 2 users
#   Community 388: 2 users
#   Community 390: 2 users
#   Community 391: 2 users
#   Community 392: 2 users
#   Community 393: 2 users
#   Community 394: 2 users
#   Community 395: 2 users
#   Community 398: 2 users
#   Community 403: 2 users
#   Community 404: 2 users
#   Community 405: 2 users
#   Community 406: 2 users
#   Community 407: 2 users
#   Community 408: 2 users
#   Community 409: 2 users
#   Community 412: 2 users
#   Community 413: 2 users
#   Community 414: 2 users
#   Community 417: 2 users
#   Community 418: 2 users
#   Community 419: 2 users
#   Community 421: 2 users
#   Community 422: 2 users
#   Community 423: 2 users
#   Community 424: 2 users
#   Community 425: 2 users
#   Community 427: 2 users
#   Community 428: 2 users
#   Community 429: 2 users
#   Community 430: 2 users
#   Community 431: 2 users
#   Community 436: 2 users
#   Community 437: 2 users
#   Community 440: 2 users
#   Community 444: 2 users
#   Community 448: 2 users
#   Community 449: 2 users
#   Community 450: 2 users
#   Community 453: 2 users
#   Community 454: 2 users
#   Community 455: 2 users
#   Community 457: 2 users
#   Community 459: 2 users
#   Community 463: 2 users
#   Community 466: 2 users
#   Community 468: 2 users
#   Community 469: 2 users
#   Community 471: 2 users
#   Community 473: 2 users
#   Community 475: 2 users
#   Community 477: 2 users
#   Community 479: 2 users
#   Community 480: 2 users
#   Community 481: 2 users
#   Community 484: 2 users
#   Community 485: 2 users
#   Community 486: 2 users
#   Community 487: 2 users
#   Community 493: 2 users
#   Community 496: 2 users
#   Community 497: 2 users
#   Community 501: 2 users
#   Community 503: 2 users
#   Community 509: 2 users
#   Community 511: 2 users
#   Community 512: 2 users
#   Community 514: 2 users
#   Community 515: 2 users
#   Community 517: 2 users
#   Community 518: 2 users
#   Community 519: 2 users
#   Community 520: 2 users
#   Community 521: 2 users
#   Community 522: 2 users
#   Community 523: 2 users
#   Community 525: 2 users
#   Community 534: 2 users
#   Community 537: 2 users
#   Community 540: 2 users
#   Community 541: 2 users
#   Community 544: 2 users
#   Community 547: 2 users
#   Community 549: 2 users
#   Community 551: 2 users
#   Community 553: 2 users
#   Community 554: 2 users
#   Community 556: 2 users
#   Community 559: 2 users
#   Community 562: 2 users
#   Community 563: 2 users
#   Community 564: 2 users
#   Community 565: 2 users
#   Community 566: 2 users
#   Community 568: 2 users
#   Community 569: 2 users
#   Community 572: 2 users
#   Community 573: 2 users
#   Community 574: 2 users
#   Community 576: 2 users
#   Community 577: 2 users
#   Community 580: 2 users
#   Community 581: 2 users
#   Community 585: 2 users
#   Community 586: 2 users
#   Community 587: 2 users
#   Community 590: 2 users
#   Community 595: 2 users
#   Community 596: 2 users
#   Community 602: 2 users
#   Community 604: 2 users
#   Community 605: 2 users
#   Community 606: 2 users
#   Community 607: 2 users
#   Community 609: 2 users
#   Community 611: 2 users
#   Community 612: 2 users
#   Community 613: 2 users
#   Community 617: 2 users
#   Community 619: 2 users
#   Community 620: 2 users
#   Community 621: 2 users
#   Community 622: 2 users
#   Community 623: 2 users
#   Community 625: 2 users
#   Community 627: 2 users
#   Community 628: 2 users
#   Community 630: 2 users
#   Community 633: 2 users
#   Community 634: 2 users
#   Community 635: 2 users
#   Community 636: 2 users
#   Community 640: 2 users
#   Community 642: 2 users
#   Community 644: 2 users
#   Community 646: 2 users
#   Community 647: 2 users
#   Community 650: 2 users
#   Community 651: 2 users
#   Community 653: 2 users
#   Community 654: 2 users
#   Community 656: 2 users
#   Community 657: 2 users
#   Community 658: 2 users
#   Community 659: 2 users
#   Community 660: 2 users
#   Community 661: 2 users
#   Community 662: 2 users
#   Community 665: 2 users
#   Community 666: 2 users
#   Community 667: 2 users
#   Community 671: 2 users
#   Community 673: 2 users
#   Community 674: 2 users
#   Community 680: 2 users
#   Community 682: 2 users
#   Community 683: 2 users
#   Community 686: 2 users
#   Community 688: 2 users
#   Community 689: 2 users
#   Community 0: 1 users
#   Community 5: 1 users
#   Community 17: 1 users
#   Community 30: 1 users
#   Community 65: 1 users
#   Community 72: 1 users
#   Community 88: 1 users
#   Community 119: 1 users
#   Community 133: 1 users
#   Community 149: 1 users
#   Community 162: 1 users
#   Community 169: 1 users
#   Community 214: 1 users
#   Community 215: 1 users
#   Community 216: 1 users
#   Community 224: 1 users
#   Community 226: 1 users
#   Community 233: 1 users
#   Community 252: 1 users
#   Community 253: 1 users
#   Community 254: 1 users
#   Community 258: 1 users
#   Community 261: 1 users
#   Community 268: 1 users
#   Community 284: 1 users
#   Community 288: 1 users
#   Community 290: 1 users
#   Community 293: 1 users
#   Community 294: 1 users
#   Community 295: 1 users
#   Community 297: 1 users
#   Community 302: 1 users
#   Community 303: 1 users
#   Community 304: 1 users
#   Community 307: 1 users
#   Community 317: 1 users
#   Community 321: 1 users
#   Community 326: 1 users
#   Community 329: 1 users
#   Community 330: 1 users
#   Community 332: 1 users
#   Community 343: 1 users
#   Community 349: 1 users
#   Community 350: 1 users
#   Community 351: 1 users
#   Community 352: 1 users
#   Community 361: 1 users
#   Community 368: 1 users
#   Community 370: 1 users
#   Community 371: 1 users
#   Community 372: 1 users
#   Community 375: 1 users
#   Community 389: 1 users
#   Community 399: 1 users
#   Community 400: 1 users
#   Community 415: 1 users
#   Community 434: 1 users
#   Community 435: 1 users
#   Community 445: 1 users
#   Community 446: 1 users
#   Community 447: 1 users
#   Community 452: 1 users
#   Community 460: 1 users
#   Community 462: 1 users
#   Community 470: 1 users
#   Community 478: 1 users
#   Community 483: 1 users
#   Community 488: 1 users
#   Community 489: 1 users
#   Community 492: 1 users
#   Community 504: 1 users
#   Community 510: 1 users
#   Community 533: 1 users
#   Community 536: 1 users
#   Community 571: 1 users
#   Community 578: 1 users
#   Community 583: 1 users
#   Community 591: 1 users
#   Community 599: 1 users
#   Community 615: 1 users
#   Community 629: 1 users
#   Community 632: 1 users
#   Community 664: 1 users

# %%
#  Modularity Score 
# Measures quality of the partition (0 = random, 1 = perfect communities)
modularity = community_louvain.modularity(partition, G_undirected)
print(f"\nModularity Score: {modularity:.4f}")

#  Who are the top users in each community? 
# This is what satisfies the PG interpretation requirement
print("\nTop users per community (by degree):")
for comm_id in sorted(community_counts.keys()):
    # get all users in this community
    members = [node for node, comm in partition.items() if comm == comm_id]
    # rank by degree within the full graph
    top = sorted(members, key=lambda n: G_undirected.degree(n), reverse=True)[:3]
    print(f"  Community {comm_id} ({len(members)} users): {top}")
# Out:
# Modularity Score: 0.9937
#
# Top users per community (by degree):
#   Community 0 (1 users): ['@BODHI-h6j']
#   Community 1 (3 users): ['@john_d_91', '@MichaelMartinez-ds1vd', '@GuitarCovers124']
#   Community 2 (2 users): ['@MarshEllo189roblox', '@SolidState5150']
#   Community 3 (2 users): ['@T3alnPurpl3Show', '@lettuce_head4']
#   Community 4 (2 users): ['@STAYS_0NLY', '@kimreiling2805']
#   Community 5 (1 users): ['@confxetti']
#   Community 6 (2 users): ['@CherylKasson', '@meladejesus']
#   Community 7 (2 users): ['@Isabobi', '@ab.7272']
#   Community 8 (2 users): ['@Ghost_EaterYT', '@user-pw6mk5gf9i']
#   Community 9 (3 users): ['@Welcometoworlder', '@ultimate98media', '@logicking3765']
#   Community 10 (2 users): ['@Stelbri', '@kintober']
#   Community 11 (2 users): ['@SatisfiedBeastYT', '@ChadForquer']
#   Community 12 (3 users): ['@SnoopySnoopy0', '@Stadtaxer26', '@RalphJBater']
#   Community 13 (2 users): ['@Abdulmalik73836', '@philosophyenjoyer']
#   Community 14 (2 users): ['@NeptuniaMorgan', '@Lexi_Frids3']
#   Community 15 (2 users): ['@bob-t2f4v', '@SunbleachedAngel']
#   Community 16 (3 users): ['@ShaddoeJ', '@Lucidij', '@mb2233']
#   Community 17 (1 users): ['@1ireynthecool']
#   Community 18 (9 users): ['@mohanjan8768', '@mranima748', '@TheIkon202']
#   Community 19 (7 users): ['@IdioticSeal', '@kuroart86', '@AndrewGold-ko7rj']
#   Community 20 (16 users): ['@cheyheyy', '@dreamcaught3876', '@catbardsandmover']
#   Community 21 (4 users): ['@xdflame7712', '@Supersoccerchic', '@perona.s_bath_water3838']
#   Community 22 (2 users): ['@I_like_my_dad', '@AlwaysTryingToBeABetterHuman']
#   Community 23 (2 users): ['@Clip_It1', '@kristinayeh6364']
#   Community 24 (2 users): ['@oszievavoxrv3154', '@YourMyGamingLife']
#   Community 25 (2 users): ['@Savage1234yt', '@Danithegamersoasis']
#   Community 26 (8 users): ['@RoronaEdits', '@OreoKing-Yt', '@GGISALIEN']
#   Community 27 (2 users): ['@isaiah-zp5tr', '@ErikJ1218']
#   Community 28 (2 users): ['@PeterS-r4o', '@elbee1771']
#   Community 29 (2 users): ['@ShockBlotBow', '@g00fyLesb1an']
#   Community 30 (1 users): ['@ThePrimeMinisterOfTheBlock']
#   Community 31 (2 users): ['@AlMaJo12', '@h_a_n_s_i_l_u']
#   Community 32 (2 users): ['@debitastaggovitch', '@MaxDeckard']
#   Community 33 (2 users): ['@sailoroftheinternet3290', '@TooChillery']
#   Community 34 (2 users): ['@Dani.Space15', '@Electric_Scooter_World']
#   Community 35 (2 users): ['@ednamartinez6129', '@Mr-pn2eh']
#   Community 36 (4 users): ['@ASMR_Orangely', '@Chaoitcme', '@markshuggah']
#   Community 37 (3 users): ['@SoleilMagica', '@daanbondt3167', '@Valentino-t5w']
#   Community 38 (2 users): ['@acborgia1344', '@barney_huzi3622']
#   Community 39 (2 users): ['@arianajordan', '@Grayest_Fox']
#   Community 40 (2 users): ['@jamieexo7542', '@toddjohnson0306']
#   Community 41 (4 users): ['@TehDeminz', '@brettmuller7918', '@FeelMyFlame1']
#   Community 42 (2 users): ['@alakazam482', '@wtfusheeple5383']
#   Community 43 (2 users): ['@MickUhrenholt', '@pseudo-risto']
#   Community 44 (2 users): ['@SAMUEL-LE-IX', '@MyMEDFITNESS']
#   Community 45 (2 users): ['@lubskipunch8706', '@discoverbitcoin4335']
#   Community 46 (2 users): ['@chiefcrazyhorse', '@joelfarber3261']
#   Community 47 (3 users): ['@eoinMB3949', '@drewgoodman7932', '@dangtran6657']
#   Community 48 (10 users): ['@LabMuffinBeautyScience', '@doctor-abby', '@resi2120']
#   Community 49 (2 users): ['@Jaimie-w9t', '@Bebopeep']
#   Community 50 (5 users): ['@KlaraTshiamo', '@liveforlife2494', '@Chocolatindo']
#   Community 51 (2 users): ['@mandyleexart6396', '@Eff_It']
#   Community 52 (2 users): ['@dreambrush7251', '@Samino4ka']
#   Community 53 (13 users): ['@msmichelle2196', '@FentonTheIIV', '@RoamingREDonFIRE']
#   Community 54 (10 users): ['@waspwrap1235', '@johndavidson5921', '@johnnybrownjr7214']
#   Community 55 (7 users): ['@charlesquesnel2302', '@Er_Guille', '@GLABSPC']
#   Community 56 (3 users): ['@Sans_The_Skeleton', '@mercijoy3006', '@TremaineAkeWriting']
#   Community 57 (2 users): ['@swiftdragonrider', '@fitwithjr9051']
#   Community 58 (2 users): ['@irfanizzrusyaidi', '@brandondrew739']
#   Community 59 (2 users): ['@aaaaa111aaaaa', '@T-Appear']
#   Community 60 (6 users): ['@nauticlipse', '@angel-fz8qg', '@kemppalmer3540']
#   Community 61 (6 users): ['@AmandaAllen-c2q', '@Leen-qz6il', '@desolatesoul2304']
#   Community 62 (5 users): ['@Gamer-dude247', '@jimcarreyfan24', '@jonathonharris1758']
#   Community 63 (5 users): ['@sofiabamhamed8507', '@Anela-v2f', '@prettyloubey8411']
#   Community 64 (2 users): ['@arkanahmed4520', '@dianathompson4004']
#   Community 65 (1 users): ['@helenokezie1614']
#   Community 66 (2 users): ['@AstraeaJustice', '@yannaytigafwygsamid557']
#   Community 67 (5 users): ['@Mary09792', '@supercorp45', '@cc2118']
#   Community 68 (2 users): ['@liddobabylala', '@Hormoniverse']
#   Community 69 (2 users): ['@Picasso-x4w', '@inesar1993']
#   Community 70 (26 users): ['@Vegan_Vlogs', '@jamesshepard2672', '@twotonrhinottr2877']
#   Community 71 (2 users): ['@zonnebloemsummer6435', '@jessicahay9305']
#   Community 72 (1 users): ['@MMlilFamily']
#   Community 73 (2 users): ['@carissaexplainsitall8481', '@Kanu22']
#   Community 74 (2 users): ['@Ktakahashi18', '@neechi_97']
#   Community 75 (2 users): ['@yayeet8879', '@kittyjuneo2218']
#   Community 76 (2 users): ['@limebeansg', '@Tolly652']
#   Community 77 (2 users): ['@archigoel', '@kavericornett6748']
#   Community 78 (4 users): ['@MK-ih6wp', '@dogtorhouse', '@AmySunstrum']
#   Community 79 (2 users): ['@bloomsandbeams3272', '@nellystepchin975']
#   Community 80 (2 users): ['@blackangel712', '@bruceyoung565']
#   Community 81 (6 users): ['@Inventor1488', '@1trschaefer78', '@TheDOS']
#   Community 82 (2 users): ['@jacktinney', '@skippy6462']
#   Community 83 (2 users): ['@c.d.7491', '@ThePrimalmotivation']
#   Community 84 (2 users): ['@AngelaAsks', '@blikewat3r']
#   Community 85 (2 users): ['@larapalma3744', '@corgisrule21']
#   Community 86 (2 users): ['@SullivanKelly85', '@tinagrizzle777']
#   Community 87 (8 users): ['@BleachedBlackSocks', '@zaplanar', '@mrwooomaker5606']
#   Community 88 (1 users): ['@lynette3021']
#   Community 89 (4 users): ['@ClevverUsername', '@luckyDancer100', '@CinnaBanBanRoll']
#   Community 90 (3 users): ['@kattehkittyable', '@kguzman1719', '@faithcritchfield1066']
#   Community 91 (2 users): ['@ChyocoLaytte', '@Sixxlet44']
#   Community 92 (2 users): ['@pedros7341', '@electron-Volt']
#   Community 93 (2 users): ['@Xgennn57', '@inthegrass11']
#   Community 94 (2 users): ['@simomis4', '@Thisone109']
#   Community 95 (2 users): ['@hedgehog3180', '@contentweaverz2438']
#   Community 96 (3 users): ['@Bitofa_nerd', '@jeanniemaycrawford4466', '@deoyx']
#   Community 97 (4 users): ['@Trysalis12', '@hyperion4482', '@stlslayerac']
#   Community 98 (7 users): ['@janedough6575', '@Amy_Lou1177', '@TheCherylish1']
#   Community 99 (2 users): ['@Oexciting', '@Schwester973T']
#   Community 100 (3 users): ['@cindyslevin3075', '@MerridethHawk', '@senadasejdic582']
#   Community 101 (2 users): ['@КонстантинЯлынычев', '@human_creature']
#   Community 102 (2 users): ['@marianne1959', '@debbiemachelle2703']
#   Community 103 (2 users): ['@gloriat8071', '@K4113B4113']
#   Community 104 (3 users): ['@jijicatt', '@BigPictureYT', '@CJ-so3tt']
#   Community 105 (6 users): ['@EmptyTheTanks', '@Ladynipchick2', '@ReasonablySpeaking9808']
#   Community 106 (2 users): ['@eegarim', '@BarbaraAllen-Bolger']
#   Community 107 (3 users): ['@ericwanyonyi2445', '@dianeweesner4274', '@giazillashow']
#   Community 108 (3 users): ['@sipnscoot3049', '@pedroflovera', '@wynw7214']
#   Community 109 (3 users): ['@Blickos456', '@hOurworld11', '@trevormillin506']
#   Community 110 (11 users): ['@durece100', '@kalyispie', '@14Pestarzt88']
#   Community 111 (3 users): ['@juanesteban8827', '@Trill-Is-Real', '@RedditAthiest']
#   Community 112 (2 users): ['@dr.zoidberg8666', '@MrGelato41']
#   Community 113 (2 users): ['@jmpompey1', '@alexandromonges8850']
#   Community 114 (2 users): ['@DafodyllLane', '@Kewteepoi']
#   Community 115 (3 users): ['@Intrusiveq', '@DurrutiColumn', '@willo7734']
#   Community 116 (2 users): ['@BartholomewFrederickTheThird', '@FL0ra_favvn']
#   Community 117 (4 users): ['@roycereinhardt3763', '@Flawless_R', '@Comrade-Alpaca']
#   Community 118 (5 users): ['@DjangoDoesStuff', '@thecozyintrovert', '@chriskazaam896']
#   Community 119 (1 users): ['@b0wixe']
#   Community 120 (8 users): ['@truthseekingtroll3575', '@kzdp_ae', '@AlMc-j2y']
#   Community 121 (3 users): ['@DF-ju4cw', '@carlo8593', '@kenny2006sp']
#   Community 122 (3 users): ['@freedomlover2358', '@MrsFearEstate', '@erincoughlin4187']
#   Community 123 (2 users): ['@Blissed-Out', '@happierabroad']
#   Community 124 (53 users): ['@gwenspacetraveler', '@Dj87887', '@henriklarsson5221']
#   Community 125 (2 users): ['@nel9732', '@TwattyWankers']
#   Community 126 (3 users): ['@martinfricek4787', '@LorrieBell-p3e', '@xsaber7']
#   Community 127 (3 users): ['@posivibe989', '@syedyakub5849', '@thomasvoorham6374']
#   Community 128 (7 users): ['@Roswell33', '@FTech-k3u', '@MillyM-ze3ic']
#   Community 129 (2 users): ['@kayden1257', '@Psalms91-111']
#   Community 130 (3 users): ['@fabriciorodriguez5788', '@winktonsmom6965', '@brotherEbenezer']
#   Community 131 (2 users): ['@mohdshuai7684', '@travisvanalst4698']
#   Community 132 (4 users): ['@suzannewieler5384', '@tsamseli', '@cocos.9730']
#   Community 133 (1 users): ['@danielvarela5519']
#   Community 134 (2 users): ['@lorenzoic', '@lakshmikandahari5746']
#   Community 135 (4 users): ['@championshipjackets4496', '@amersayeed1238', '@uttamsankhyan383']
#   Community 136 (2 users): ['@DaveDave-o4w', '@RavenWolf2moons']
#   Community 137 (2 users): ['@sophiepauldingkopecky4773', '@lelelele2-j5e']
#   Community 138 (2 users): ['@agreeablegraylife', '@classatv5876']
#   Community 139 (5 users): ['@DrBradStanfield', '@advertiserfriendlyusername5362', '@theradicalaxe553']
#   Community 140 (3 users): ['@cxw5412', '@kimb5245', '@TimMorrello.0145']
#   Community 141 (2 users): ['@danielmuilenburg5363', '@drop_0utttt']
#   Community 142 (12 users): ['@AndreBettinson', '@7israelll', '@Replicant-by1eh']
#   Community 143 (2 users): ['@marko-182', '@FostRaider']
#   Community 144 (3 users): ['@teomanko', '@rayohanlon2355', '@30yyears']
#   Community 145 (2 users): ['@rodenwald', '@danielpad5803']
#   Community 146 (3 users): ['@WilliamSmithers-g4f', '@Trollseeder', '@KemarMcbean-zx1rv']
#   Community 147 (2 users): ['@tarekj5951', '@YoungChosen13']
#   Community 148 (2 users): ['@MrGalaxyY1', '@terric703']
#   Community 149 (1 users): ['@alexanderwanghofer4989']
#   Community 150 (2 users): ['@SunRise-ou1pb', '@city5224']
#   Community 151 (2 users): ['@mikeymike-m7o', '@ThunderWizard']
#   Community 152 (2 users): ['@toasttime9266', '@monarchu']
#   Community 153 (2 users): ['@wholeNwon', '@curiouslyeternal']
#   Community 154 (2 users): ['@TunaStrata', '@Pedzisai-Makura']
#   Community 155 (5 users): ['@Smart_Chick_', '@你是杰瑞吗', '@workingtunafish']
#   Community 156 (2 users): ['@survivorfandan_sa9', '@jillschneider2953']
#   Community 157 (6 users): ['@foyivostanley5495', '@tlpineapple1', '@joywebster2678']
#   Community 158 (3 users): ['@DrGirthBrooks', '@kevinjubbalmd', '@Dunve']
#   Community 159 (2 users): ['@annoyedcat9291', '@jovanrodriguez4057']
#   Community 160 (4 users): ['@vanntooot', '@wideeyewanderer1785', '@abcxyz9168']
#   Community 161 (2 users): ['@treasajanette7350', '@megustAslagt']
#   Community 162 (1 users): ['@JCResDoc94']
#   Community 163 (2 users): ['@lifeisgood628', '@kabirdoc70']
#   Community 164 (2 users): ['@papongpapong1047', '@mcslammer4989']
#   Community 165 (2 users): ['@manuelfernandeztato2185', '@msz9523']
#   Community 166 (4 users): ['@RachelSouthard', '@josephdahdouh2725', '@yellow8206']
#   Community 167 (2 users): ['@farrelodjo6054', '@richd61']
#   Community 168 (31 users): ['@Charlesco', '@jimmynjebayi1437', '@marieange5297']
#   Community 169 (1 users): ['@emichen9077']
#   Community 170 (2 users): ['@djawedaloui2404', '@drik-c9722']
#   Community 171 (3 users): ['@baptisteguilloteau3366', '@victoriavictoria982', '@lanagardner92']
#   Community 172 (2 users): ['@alyssablunt7014', '@yolunik']
#   Community 173 (4 users): ['@toriakanohi', '@fabiz1379', '@lindary7838']
#   Community 174 (23 users): ['@drjayeshsharma', '@sbaba8458', '@kavitasihag1']
#   Community 175 (2 users): ['@MarvellousMaha', '@SairaSabir-1447AH']
#   Community 176 (2 users): ['@arpita.17-m7x', '@va4488']
#   Community 177 (6 users): ['@hellotonybaby6258', '@salmakausar8209', '@deepamurali9881']
#   Community 178 (5 users): ['@princyprincesss4572', '@dr.hasan_medicine', '@m_varsh']
#   Community 179 (21 users): ['@mephistomadeadeal', '@josebraga8645', '@tdbst-du']
#   Community 180 (2 users): ['@rosimeridasilva5193', '@magalhaes3943']
#   Community 181 (2 users): ['@lucianocandido2713', '@rogekano']
#   Community 182 (2 users): ['@rawmeat.dasilva', '@1est1']
#   Community 183 (2 users): ['@Rafaellrg', '@gabrielmoreira447']
#   Community 184 (2 users): ['@HenriquedeCamargoBricoleri', '@mariacristinaandrades6007']
#   Community 185 (2 users): ['@Cristianesoares7', '@yanhendryk3260']
#   Community 186 (2 users): ['@natherciarangel3836', '@jorgepaula1679']
#   Community 187 (2 users): ['@Nerdolafilmes', '@deborahelenaastrologa']
#   Community 188 (2 users): ['@phellipecarvalho8133', '@fv9400']
#   Community 189 (2 users): ['@emagreça_correndo', '@chanelbaby7015']
#   Community 190 (2 users): ['@daniloberserk', '@angelotantra9326']
#   Community 191 (2 users): ['@Yzy.BoneSaw', '@daniell5751']
#   Community 192 (2 users): ['@eaglesfc4791', '@clubdascorujas449']
#   Community 193 (2 users): ['@zeliadias3246', '@everliwohl3126']
#   Community 194 (2 users): ['@TheRejustine', '@hugodacosta137']
#   Community 195 (2 users): ['@nicholasmachado1288', '@Princeso2k']
#   Community 196 (2 users): ['@marvelitegirl', '@LDtincuff']
#   Community 197 (2 users): ['@Damn-Sandwich', '@bass_freak']
#   Community 198 (14 users): ['@CR7XLM10-d7r', '@Itzicebeatz', '@flozziesfoe']
#   Community 199 (2 users): ['@phibians', '@mac1lambo2']
#   Community 200 (2 users): ['@lordmat', '@harsxit']
#   Community 201 (3 users): ['@Petro250', '@davidteegray9730', '@meatabolic']
#   Community 202 (9 users): ['@LightyAE', '@Melon-pp2zb', '@liluzidiamondpiercing']
#   Community 203 (5 users): ['@rationalchristian', '@ImuBozu', '@ReelRiftYT']
#   Community 204 (4 users): ['@tokyo-y5e', '@boiwhatthehellboi5102', '@ChewyBatz']
#   Community 205 (5 users): ['@jks9751', '@Iclops', '@xruxix']
#   Community 206 (56 users): ['@DoctorMike', '@Casey_King', '@user-gc2en6bk5o']
#   Community 207 (2 users): ['@illitluvieee', '@enpetal.ৎ']
#   Community 208 (2 users): ['@Zahraandzayda', '@KyleZeEnabler']
#   Community 209 (6 users): ['@novarealaccount', '@Løst-z3r', '@TheELTstarfromYT']
#   Community 210 (2 users): ['@Miss._.Shortcakeee', '@nilayfromnashik']
#   Community 211 (2 users): ['@TrafficConeEnjoyer', '@Share_God_witheveryone']
#   Community 212 (2 users): ['@TGSITW', '@ItzKrazyCrystal']
#   Community 213 (3 users): ['@Speedsta123', '@starshine_wezie', '@DanielGarcia-wt9if']
#   Community 214 (1 users): ['@miked69046']
#   Community 215 (1 users): ['@bryanrushlow8804']
#   Community 216 (1 users): ['@KhalfanAli-l6u']
#   Community 217 (7 users): ['@thomasdoserandomstuff3795', '@mastershotznv', '@Fart-Simpson-r4k']
#   Community 218 (2 users): ['@TheCelestialDimensionalShow', '@Nalia232-d3f']
#   Community 219 (3 users): ['@azure22606', '@MorganBean-i6u', '@Matthew-co2jb']
#   Community 220 (5 users): ['@TysonLor-z7o3g', '@ahmed78yearsago70', '@thepsychicspoon5984']
#   Community 221 (2 users): ['@srikarprabhu1553', '@SAGIPLAYZZZ']
#   Community 222 (4 users): ['@jeannevolneskakis', '@Waylessmilo', '@Kem-y2y']
#   Community 223 (2 users): ['@confusedithink', '@daytonmitchell6773']
#   Community 224 (1 users): ['@TheSpecialG1nger']
#   Community 225 (2 users): ['@Ambatron-l7o', '@Beanbagbuffalo']
#   Community 226 (1 users): ['@cptncrispy69']
#   Community 227 (3 users): ['@thatweird_girl', '@goalkeeper25-v1z', '@berryrpsss']
#   Community 228 (2 users): ['@Moøny_WCUE', '@BobbyBrownnnnn']
#   Community 229 (2 users): ['@36i6ei', '@JuiceBoxBobo']
#   Community 230 (2 users): ['@gts-corner', '@Helljumper91']
#   Community 231 (7 users): ['@jjtx4514', '@Nibeaun', '@ElizabethFigel']
#   Community 232 (2 users): ['@memorysnake1646', '@Grey-the-gey']
#   Community 233 (1 users): ['@christopherbrown1187']
#   Community 234 (2 users): ['@maximus-t9b4e', '@Fomites']
#   Community 235 (2 users): ['@vausnik', '@Glue_sniffer-132']
#   Community 236 (2 users): ['@BeeMcDee', '@scottreich1207']
#   Community 237 (2 users): ['@GamesManiaOfficial', '@andreafionda542']
#   Community 238 (2 users): ['@celinaroll', '@Witmare']
#   Community 239 (2 users): ['@Maxfromohio2155', '@Alicia-k4b7u']
#   Community 240 (2 users): ['@Luffyximu', '@stephaniestyrcula453']
#   Community 241 (2 users): ['@susan825', '@downwithcensorship131']
#   Community 242 (2 users): ['@yahiabhisachhai8025', '@sadiyasultana9797']
#   Community 243 (2 users): ['@VinceP1974', '@howardroth3700']
#   Community 244 (2 users): ['@L3vitate-r6y', '@arabellaa214']
#   Community 245 (2 users): ['@JakeDavis-vh1js', '@BartMesser-n1c']
#   Community 246 (2 users): ['@SCPKing1835', '@RichardKatchuik']
#   Community 247 (2 users): ['@username69-l1n', '@Notoplays']
#   Community 248 (6 users): ['@exact.pressure', '@LittleGreenXD101', '@yayapapacool']
#   Community 249 (2 users): ['@agnes_ww', '@ducklinggaming4']
#   Community 250 (3 users): ['@Elise-x06h', '@blossomblox24', '@bhanelt']
#   Community 251 (3 users): ['@number15burgerking', '@xkillerwolfymc', '@wotcpunk103']
#   Community 252 (1 users): ['@Arousha-g2o']
#   Community 253 (1 users): ['@AlexPearce-mp3td']
#   Community 254 (1 users): ['@2018-bm9']
#   Community 255 (2 users): ['@BloodbagDaYeen', '@LinnéaTaube-z8i']
#   Community 256 (2 users): ['@Adamsamson2010', '@DinoEarthZ']
#   Community 257 (2 users): ['@FelixWillFiddleYou', '@nickstanovic']
#   Community 258 (1 users): ['@EszterKurunczi']
#   Community 259 (2 users): ['@Purple_Kitty-14', '@SavannahTiffault']
#   Community 260 (6 users): ['@DoctorER', '@afibuffygirl', '@josealejandrosotodonoso']
#   Community 261 (1 users): ['@josh_gaming0']
#   Community 262 (2 users): ['@Superbus-Pasha', '@AuthorizedBlaze']
#   Community 263 (2 users): ['@vemonsnake-t8z', '@VenomSnake9']
#   Community 264 (4 users): ['@FushKruja-i9e', '@Bumbaclartios', '@homik144']
#   Community 265 (2 users): ['@Chancellor2014', '@non67kid']
#   Community 266 (4 users): ['@MrBeast', '@AmbitiousPH', '@Okay942']
#   Community 267 (2 users): ['@Az_real0', '@Joy-j6l9s']
#   Community 268 (1 users): ['@AgentBluejay']
#   Community 269 (3 users): ['@lindseyhiggins5929', '@TheRealGatorBoy2011', '@Aesthetically-Jessie']
#   Community 270 (2 users): ['@notvalk5475', '@beverlychillsnyc']
#   Community 271 (2 users): ['@OP81JAZBLI', '@roryloe3414']
#   Community 272 (2 users): ['@tommyJC1994', '@justfulname']
#   Community 273 (2 users): ['@Mystery1352ze', '@natkr190']
#   Community 274 (4 users): ['@Littlekomono', '@plushiefactory9742', '@jennahaworth3613']
#   Community 275 (4 users): ['@shesheyk', '@Suu.1vyy', '@4eCL18']
#   Community 276 (2 users): ['@neSMOTRInaAVUkanala', '@elia_m06']
#   Community 277 (3 users): ['@arimaster-v1z', '@AmarMedhat', '@pouyan_m']
#   Community 278 (2 users): ['@umaniezealah667', '@Nøel-VRFS']
#   Community 279 (2 users): ['@answersfromscriptureonline', '@Bruh-mn5vz']
#   Community 280 (2 users): ['@PonConAgain9718', '@jujuwitzke']
#   Community 281 (2 users): ['@_sophie.love_', '@Oumumu8']
#   Community 282 (2 users): ['@Jpdubfr', '@Theoneearedcat']
#   Community 283 (3 users): ['@zylxex', '@BandsOntheMarch', '@Bluesib11']
#   Community 284 (1 users): ['@djdarwin__watterson']
#   Community 285 (2 users): ['@MeraDellOnline', '@JaksARK']
#   Community 286 (5 users): ['@jaelie8398', '@Steven8572-e4p', '@Thehomie-w9o']
#   Community 287 (6 users): ['@akherousia', '@natasha5306', '@machelawili5473']
#   Community 288 (1 users): ['@mceemoments']
#   Community 289 (2 users): ['@terryhefty', '@shrezird']
#   Community 290 (1 users): ['@AlyceWynter']
#   Community 291 (6 users): ['@ambruhzevic', '@Tracy-rf7ri', '@SaraAshley116']
#   Community 292 (2 users): ['@Hosseinghanaati', '@Franciaine29']
#   Community 293 (1 users): ['@Kat_The_Red_Fox']
#   Community 294 (1 users): ['@irachityr8656']
#   Community 295 (1 users): ['@biff-k9e']
#   Community 296 (2 users): ['@ianweston310', '@sandranodine1151']
#   Community 297 (1 users): ['@erikarabadan4924']
#   Community 298 (2 users): ['@Muchgame69420', '@Jaxsishere']
#   Community 299 (2 users): ['@sdfsdfsdfsdfsdfxcv', '@Kitty-GamerYT']
#   Community 300 (2 users): ['@daisyarteaga7240', '@iRantAndRamble']
#   Community 301 (2 users): ['@GalacticShortsz', '@CoAbOf']
#   Community 302 (1 users): ['@lifeshardgetahelmet8985']
#   Community 303 (1 users): ['@madelynnicole8272']
#   Community 304 (1 users): ['@SkyBlueDevilsNest']
#   Community 305 (3 users): ['@AliceDean-k9m', '@Nate-z9x7h', '@EvanBear']
#   Community 306 (2 users): ['@Noor-sl5ep', '@booboochild4215']
#   Community 307 (1 users): ['@jorgenborf4155']
#   Community 308 (2 users): ['@corundum-voidlessm6480', '@chademery9169']
#   Community 309 (2 users): ['@DaliaworldFriends', '@frostyfilmwatcher2148']
#   Community 310 (4 users): ['@fanrco766', '@brunomaximilianrohde9144', '@YeahNo']
#   Community 311 (2 users): ['@Mousei.8483', '@ShawnElliot-p3v']
#   Community 312 (2 users): ['@antiphon000', '@anonymouselegion']
#   Community 313 (3 users): ['@tsunamic84', '@michaeldoran4367', '@TheAlmightySmelldoor']
#   Community 314 (2 users): ['@johnhostetler2167', '@LexaTerrestrialx']
#   Community 315 (4 users): ['@xBigBean', '@thetwitchywitchy', '@Nancy-nx9dm']
#   Community 316 (2 users): ['@lolooo1050', '@mimichan5306']
#   Community 317 (1 users): ['@Catty_Corner_Movies']
#   Community 318 (2 users): ['@rhodiumtherterrible', '@Tock_Jacks']
#   Community 319 (3 users): ['@Tom_Corvus5', '@shinyman250', '@KingFloch88']
#   Community 320 (4 users): ['@anthonybachler9526', '@KiwiBubbles5', '@Saenzzy']
#   Community 321 (1 users): ['@Knowledge_snek']
#   Community 322 (2 users): ['@anikaloveshim', '@Beckers82']
#   Community 323 (2 users): ['@kramsdell0', '@TheoNguyen-i5q']
#   Community 324 (2 users): ['@YujisFavoriteMochi_172', '@adomzenith3755']
#   Community 325 (2 users): ['@Theairplaneman333', '@piercethemeli']
#   Community 326 (1 users): ['@verdeverde2763']
#   Community 327 (2 users): ['@DirectLynx', '@Moguslover']
#   Community 328 (2 users): ['@ishowmeatg7', '@velkypupokproduction4190']
#   Community 329 (1 users): ['@Itz_zorablox']
#   Community 330 (1 users): ['@Helpme134-g3c']
#   Community 331 (2 users): ['@NaaGlo', '@adc787']
#   Community 332 (1 users): ['@VirtuesProject-19']
#   Community 333 (2 users): ['@TGAGlitch4aa', '@AleciaRellum']
#   Community 334 (3 users): ['@LJThommas', '@feralsenri_5', '@thefrogguy12']
#   Community 335 (2 users): ['@Still_to_rott_band', '@timz7813']
#   Community 336 (2 users): ['@AarohisStudio', '@Slay_taytay']
#   Community 337 (2 users): ['@KenanAlomari-mk7ed', '@Tman16']
#   Community 338 (2 users): ['@JustaDancer5678', '@Demonxarehere']
#   Community 339 (3 users): ['@Juliatran4818', '@Banana-i6l', '@XylonXD']
#   Community 340 (5 users): ['@ryanm2', '@OFFICIAL_Nerd1nob', '@Jennie1929']
#   Community 341 (2 users): ['@bringnanahome', '@debbylou5729']
#   Community 342 (4 users): ['@ZaynneThaWook', '@Kinseliplier', '@jgriffithj4j']
#   Community 343 (1 users): ['@KaiserTip']
#   Community 344 (2 users): ['@jiujitsufighter91', '@alexGG1219']
#   Community 345 (4 users): ['@IllC2Ill', '@futur3ndings651', '@AngeliqueStP']
#   Community 346 (4 users): ['@Gitano-k7t', '@effefffffffffffffffffffff', '@LexiM-u8j6c']
#   Community 347 (2 users): ['@morphkogan8627', '@Love_grapes']
#   Community 348 (3 users): ['@skibidisigma1099', '@CookieYumYum-f2n', '@ZariaM2013']
#   Community 349 (1 users): ['@shrug_emoticon1']
#   Community 350 (1 users): ['@hussainalsayegh5764']
#   Community 351 (1 users): ['@griffthefithgames']
#   Community 352 (1 users): ['@SusanKenny-f5k']
#   Community 353 (2 users): ['@AlyzaRivers', '@whisperecho7815']
#   Community 354 (2 users): ['@livelifeincolour', '@daveofyorkshire301']
#   Community 355 (3 users): ['@SheHouseOnMyMDTillIWilson', '@Ms_Malpractice', '@tristanymous']
#   Community 356 (2 users): ['@dogwithsunglasses4051', '@doyinsola5525']
#   Community 357 (2 users): ['@enby_elphaba', '@udlx']
#   Community 358 (3 users): ['@OriginalTurtle-em9zk', '@perplexingHodgepodge', '@Kayla-c9y8s']
#   Community 359 (2 users): ['@Tuiiim1', '@scalylayde8751']
#   Community 360 (3 users): ['@Belormoroth', '@Cefadroxil_23', '@ProgrammingWithKeith']
#   Community 361 (1 users): ['@Tcbmamma']
#   Community 362 (4 users): ['@tinatoste-smock9966', '@jls4382', '@juliescott1504']
#   Community 363 (2 users): ['@polythenespam3933', '@beverlystufflebeam5731']
#   Community 364 (6 users): ['@Lipsyberry', '@LianaKlohn', '@k16ha61h2']
#   Community 365 (2 users): ['@alexmarin1395', '@Ramirez2523']
#   Community 366 (2 users): ['@Naj1811', '@murphle-k8n']
#   Community 367 (2 users): ['@TylorHanson', '@Mr-murkey-man']
#   Community 368 (1 users): ['@lincolnmerz4415']
#   Community 369 (2 users): ['@AMIPLAYSSS_082', '@Everestsdragons']
#   Community 370 (1 users): ['@KailiPlaysYT']
#   Community 371 (1 users): ['@魏子杰-p2m']
#   Community 372 (1 users): ['@sarahferrell5458']
#   Community 373 (2 users): ['@Felixxxxx555', '@quin.107']
#   Community 374 (2 users): ['@aleksanaification', '@teem4326']
#   Community 375 (1 users): ['@AlexBaythavong-v1s']
#   Community 376 (2 users): ['@arandompoleontheinternet', '@TheCalmGuy_Playz']
#   Community 377 (3 users): ['@Ganman5000yt', '@EmilyParksAtlanta', '@AstrumKitten091']
#   Community 378 (3 users): ['@JAYDENCHONGCHILAMMoe', '@Yizzy-h79', '@haileyye.ིྀ']
#   Community 379 (2 users): ['@SerialDesignationN-k3h', '@Pattwon']
#   Community 380 (2 users): ['@JJC991', '@ThukunaAep']
#   Community 381 (2 users): ['@MokoWithCousins', '@deepblueskys']
#   Community 382 (2 users): ['@Heaven_Jr-9', '@Monkeyman-1205']
#   Community 383 (2 users): ['@LP_jumpingOFF', '@posiethepopstarisgone']
#   Community 384 (2 users): ['@SoetZenas', '@marcusd4366']
#   Community 385 (4 users): ['@JsEli28', '@BRIMARFC', '@tazbidalbari']
#   Community 386 (2 users): ['@Misstind1e', '@ExampleChannel-i2d']
#   Community 387 (3 users): ['@solitudeguardswood', '@BMA263', '@schuii6195']
#   Community 388 (2 users): ['@idontknowwhoiambutthesexgoeson', '@gokuglazerhehehe']
#   Community 389 (1 users): ['@Dd44wgWhat']
#   Community 390 (2 users): ['@Insonima74', '@infinitegamer-g3y']
#   Community 391 (2 users): ['@daveausmunchen7787', '@DanielConstantinoS']
#   Community 392 (2 users): ['@Westbug76807', '@day.ebrahim']
#   Community 393 (2 users): ['@becauseiamaaron', '@ooohhhh-y5v']
#   Community 394 (2 users): ['@CyborgDoge', '@AtlasFalls']
#   Community 395 (2 users): ['@JospehMamabolo', '@Neonized626']
#   Community 396 (4 users): ['@cool3Dhorse', '@HarshKumar-gh9uc', '@scottwesner9362']
#   Community 397 (3 users): ['@Rushi_don', '@MrKody32', '@PhysiologyWithZaid']
#   Community 398 (2 users): ['@apurvpatel1310', '@yellowswimmingxcfddfghjjhv8128']
#   Community 399 (1 users): ['@ultrainstinctgokublack021']
#   Community 400 (1 users): ['@Tsukikiba_521']
#   Community 401 (3 users): ['@MiaJohnson-x4m', '@Your_average_oxygen_enjoyer', '@GlobeTrotter-t1t']
#   Community 402 (3 users): ['@Breaddddddddddddddddddddddddd', '@fabi_2019', '@ritvikrao7389']
#   Community 403 (2 users): ['@SeatiesTheGoat', '@dawkosvk']
#   Community 404 (2 users): ['@drayinsane7939', '@beefjerky360']
#   Community 405 (2 users): ['@xdgmx', '@DSG145']
#   Community 406 (2 users): ['@AlbertEinst13n', '@John-lo4xz']
#   Community 407 (2 users): ['@Ironica82', '@AileenMartinez-hq2hk']
#   Community 408 (2 users): ['@Slop_Dogg', '@90sKid-Gaming']
#   Community 409 (2 users): ['@Brendan-fk3yz', '@priyankagurav']
#   Community 410 (3 users): ['@timothyjarman2308', '@Jimothy210', '@chonkeboi']
#   Community 411 (6 users): ['@WIRED', '@raho19', '@EngageYourFrontalLobe']
#   Community 412 (2 users): ['@Angelum_Band', '@NordicQueen65']
#   Community 413 (2 users): ['@churly9717', '@user-lh5nq9yi5v']
#   Community 414 (2 users): ['@685shaw', '@rose_and_thorns']
#   Community 415 (1 users): ['@Anonymous-cq5dl']
#   Community 416 (17 users): ['@sogigi', '@gregson99', '@xSilentRecon']
#   Community 417 (2 users): ['@Waeweas', '@prata6938']
#   Community 418 (2 users): ['@vtech_123', '@Qxhduifwo']
#   Community 419 (2 users): ['@kraftzion', '@TheAndyk123']
#   Community 420 (3 users): ['@KlipsenTube', '@VoidHugger', '@BrodieReid-th8gm']
#   Community 421 (2 users): ['@thebananamonk', '@wengsengtam']
#   Community 422 (2 users): ['@endlessfreefaller', '@Pixelprowess-h6c']
#   Community 423 (2 users): ['@sigmabfdiasmr', '@adityakushwaha1705']
#   Community 424 (2 users): ['@TIKTOKSECURITY-q3d', '@Lucius-wfu']
#   Community 425 (2 users): ['@palakx.velvetcore', '@oneofthesleepoverfamilyvoicers']
#   Community 426 (4 users): ['@BerryTeary', '@Norma-animallover', '@TKara-if5sz']
#   Community 427 (2 users): ['@Nana._.Rants41', '@ITSM0LLY12-h4i']
#   Community 428 (2 users): ['@lemon-s5l', '@Mildi1802']
#   Community 429 (2 users): ['@pillbuggaming', '@IanisMihaila-y3u']
#   Community 430 (2 users): ['@LivsterGrace', '@King11-k9s']
#   Community 431 (2 users): ['@bmkikaa', '@Iloveshrek_donkey31']
#   Community 432 (4 users): ['@Shinra08', '@wiltovert', '@Alexmaboi']
#   Community 433 (5 users): ['@angelycastillo5492', '@ufos-cos', '@livedbiscuitm']
#   Community 434 (1 users): ['@furtherplanet']
#   Community 435 (1 users): ['@ishannair9151']
#   Community 436 (2 users): ['@ashleeearl0712', '@Aprilcots7']
#   Community 437 (2 users): ['@OmarHejji-d3g', '@SOCALTIKIS']
#   Community 438 (3 users): ['@chavezmark_3481', '@LeilaParker-p4z', '@AvnishKumar-9892']
#   Community 439 (13 users): ['@gregXxo', '@foggypebble5159', '@DaisyDaddyy']
#   Community 440 (2 users): ['@vanderlaymedia8614', '@maverick1776.']
#   Community 441 (4 users): ['@TiredOfyoutube-d2t', '@Ignas2fly', '@rokljhui864']
#   Community 442 (4 users): ['@YoungCas1992', '@stevenperry7493', '@ZarbonTabon']
#   Community 443 (3 users): ['@tanujSE', '@Qwerboy-zv1mk', '@vladmihai306']
#   Community 444 (2 users): ['@joer5571', '@Turboy65']
#   Community 445 (1 users): ['@vocalsam3608']
#   Community 446 (1 users): ['@anjalea_ayres']
#   Community 447 (1 users): ['@EnaritaGomez']
#   Community 448 (2 users): ['@PennyChik-d4v9p', '@SonjaC-e2f']
#   Community 449 (2 users): ['@Meauxmeauxmuffin', '@nzgoldwolf6759']
#   Community 450 (2 users): ['@ERR0RGL1TCHẽDF1LEF0UND-c9u', '@Atomic_12321']
#   Community 451 (3 users): ['@Unstoppablefam', '@Diana-Aziz', '@Shmooper_Dooper']
#   Community 452 (1 users): ['@aria.jahelanishani.aviram']
#   Community 453 (2 users): ['@nikosimpleme', '@sisterskeeper8834']
#   Community 454 (2 users): ['@princessmorebucks', '@user-xd5fl3my6l']
#   Community 455 (2 users): ['@OliverBennett-x6z', '@KevinHuges']
#   Community 456 (3 users): ['@Anthem.Archives', '@RakshitAnil', '@bapulalverma8971']
#   Community 457 (2 users): ['@Aanya-kk1', '@savitrichoudhary91']
#   Community 458 (4 users): ['@LillieKane', '@pokeypickle3', '@esther.f.g']
#   Community 459 (2 users): ['@partyjerk', '@smitty2180']
#   Community 460 (1 users): ['@forestlittke4649']
#   Community 461 (3 users): ['@angelika77st', '@servantsofthemessiah720', '@averyhappybeing']
#   Community 462 (1 users): ['@TheGregfamliy']
#   Community 463 (2 users): ['@WhittleWillow', '@Lilymarah21']
#   Community 464 (3 users): ['@crunch-munch87', '@Therealandtruewilliamafton', '@smarre12']
#   Community 465 (4 users): ['@Atomix_117', '@Wds__99', '@cockyroaches']
#   Community 466 (2 users): ['@unxquespxce2792', '@ishathakor']
#   Community 467 (3 users): ['@cvcwellness', '@chaselex', '@noah8143']
#   Community 468 (2 users): ['@PickledPurple', '@umidigi.G9X']
#   Community 469 (2 users): ['@Th3RatG0d', '@JadeTheDragon4']
#   Community 470 (1 users): ['@hiblettehibbard7254']
#   Community 471 (2 users): ['@MCNBLS77890', '@Show_Love_Serina']
#   Community 472 (3 users): ['@coastaldiva', '@clea8176', '@Lauraway2']
#   Community 473 (2 users): ['@BudgetingwithFalyssa', '@MelissaFreeman']
#   Community 474 (3 users): ['@marykirmo', '@samantharitchie9148', '@UmuPadoru']
#   Community 475 (2 users): ['@StephanieBogart', '@alyssacoffey1760']
#   Community 476 (5 users): ['@GrapeCheez2', '@Mymushiesbby', '@jjbenna']
#   Community 477 (2 users): ['@stacyvettel2029', '@amandak7334']
#   Community 478 (1 users): ['@GrannyGrace']
#   Community 479 (2 users): ['@CrissPons', '@professionaldistortion']
#   Community 480 (2 users): ['@nathalieelsen7221', '@spaceparrot8702']
#   Community 481 (2 users): ['@AA-yc9dq', '@wonsavylady4458']
#   Community 482 (6 users): ['@IsabellaLanter', '@mammadingo9165', '@justhereforcomments90']
#   Community 483 (1 users): ['@Fridaygiggleclub']
#   Community 484 (2 users): ['@berryl522', '@bitsy4538']
#   Community 485 (2 users): ['@chadinacalico5006', '@aynaniyaz8213']
#   Community 486 (2 users): ['@ylenagreen4084', '@doclewis8927']
#   Community 487 (2 users): ['@Abby-ss9nl', '@tay.telaak']
#   Community 488 (1 users): ['@RebeccaMitchell-vy9rk']
#   Community 489 (1 users): ['@RatsPicklesandMusic']
#   Community 490 (14 users): ['@meowmachine9147', '@dizzylilthing', '@tarahspencernelson2844']
#   Community 491 (7 users): ['@susannahfriesenofficial', '@sukii1472', '@lis9024']
#   Community 492 (1 users): ['@van.gravies']
#   Community 493 (2 users): ['@ethereal_immaterial', '@jakeystarsuper']
#   Community 494 (6 users): ['@rawentn7016', '@QueenColleen0429', '@majkelgira2366']
#   Community 495 (3 users): ['@ulthanee', '@R0291-l1l', '@mackenziehorwath4460']
#   Community 496 (2 users): ['@biancawolf8116', '@v8h9f22']
#   Community 497 (2 users): ['@Choco-u4n', '@len519']
#   Community 498 (31 users): ['@ashleyhetherington_', '@valeriealmirola9875', '@emilyb4481']
#   Community 499 (3 users): ['@BrielleFittz', '@AvaGracePlace_116', '@BrielleFittz-u8m']
#   Community 500 (5 users): ['@rättræve', '@Marysunidiaries', '@faith_friend']
#   Community 501 (2 users): ['@the.divine.beetroot', '@srishtibatra9991']
#   Community 502 (3 users): ['@maryrosehopkins', '@perfectpitchpaola', '@BibleMemorywMusic']
#   Community 503 (2 users): ['@kthecozytrader', '@Irene.Shalom']
#   Community 504 (1 users): ['@noel.danielle']
#   Community 505 (3 users): ['@alid7754', '@marvelmolly6598', '@heidikay']
#   Community 506 (4 users): ['@millennialrx', '@julieallen1213', '@rachaelwithers7515']
#   Community 507 (4 users): ['@JustAnotherUser-rg2yp', '@buds8423', '@TheFallingGoat']
#   Community 508 (3 users): ['@abigaildaze', '@cancermoonwellness', '@Magicwithizz']
#   Community 509 (2 users): ['@lilys5515', '@katekc100']
#   Community 510 (1 users): ['@denaeoo']
#   Community 511 (2 users): ['@KatieKundalini98', '@emo__runner']
#   Community 512 (2 users): ['@Shiv_Fitlife5', '@RankAI_Official']
#   Community 513 (36 users): ['@lirilsoni', '@DineshSahoo-f6g', '@moto_hub_india']
#   Community 514 (2 users): ['@RyukendoUchiha', '@aryanqureshi8321']
#   Community 515 (2 users): ['@jewel65', '@susilopez3305']
#   Community 516 (4 users): ['@fafster6439', '@ashleymarks3726', '@CalvinHavener']
#   Community 517 (2 users): ['@thewkovacs316', '@funicon3689']
#   Community 518 (2 users): ['@Derglesnaf', '@spazzypengin']
#   Community 519 (2 users): ['@imtoolazytolookforausernam3946', '@SamIAm-w7u']
#   Community 520 (2 users): ['@scarscanbebeautiful', '@DeidresStuff']
#   Community 521 (2 users): ['@chord5625', '@LuccaRPG']
#   Community 522 (2 users): ['@rawyld', '@tammycroft6217']
#   Community 523 (2 users): ['@angelicasmodel', '@FabianGarciaRamos']
#   Community 524 (6 users): ['@JMC-125', '@BinnyBull', '@Warrickomega']
#   Community 525 (2 users): ['@Suisfonia', '@TheotherAIguy-k1g']
#   Community 526 (5 users): ['@ExplorerDS6789', '@bookfan22', '@ladyanime100']
#   Community 527 (4 users): ['@mrroboshadow', '@iamemamae', '@AnvilMAn603']
#   Community 528 (3 users): ['@GABRIELA-ACEVEDO.', '@douglastaylor9129', '@snicole042']
#   Community 529 (6 users): ['@bigboi1911-l7y', '@AA-ed6ek', '@klblythe']
#   Community 530 (6 users): ['@Hopalong_Casualty', '@laurafantoni1036', '@jacquiethebookie']
#   Community 531 (5 users): ['@vincentlucario5450', '@stanleykurtzman6621', '@mariposavioleta9007']
#   Community 532 (5 users): ['@L3m0nFzzyFzzl3', '@absolutez3r019', '@serenitymoonva']
#   Community 533 (1 users): ['@S1LLY-GooSeY']
#   Community 534 (2 users): ['@LaylaJamieson-n1n', '@HmmmUNLUCKYNAME']
#   Community 535 (3 users): ['@DoodleGoobz', '@cryingwolfuntil', '@moonstruckangelz']
#   Community 536 (1 users): ['@Odon4ta']
#   Community 537 (2 users): ['@ronjask', '@LaurenGannon-c2i']
#   Community 538 (4 users): ['@RitzyRace', '@GriffinZambia', '@thewuduroom']
#   Community 539 (4 users): ['@NONPROFIT7', '@Guyanafan', '@fingerfilms5201']
#   Community 540 (2 users): ['@Xxamber_wolfXx', '@Maetz99']
#   Community 541 (2 users): ['@dudes47327', '@robertwilson7736']
#   Community 542 (3 users): ['@danibogomolov6744', '@pkmntrainerred4247', '@benszulott67']
#   Community 543 (4 users): ['@Yuki-t4p', '@kungenbendy', '@CAINE_RAWR-XD']
#   Community 544 (2 users): ['@AlgoGhostYT', '@Jaksol_Pl']
#   Community 545 (3 users): ['@ProbluezapYT', '@Whyismynametaken', '@tobyandahalf']
#   Community 546 (6 users): ['@orceorceorce', '@jasonryan5572', '@charles-does-art']
#   Community 547 (2 users): ['@quintonhou', '@Zanatos-p4m']
#   Community 548 (5 users): ['@manakono2649', '@StrohKamel', '@helenstefanovski934']
#   Community 549 (2 users): ['@Collector_Inspector', '@my_little_panic_attack']
#   Community 550 (6 users): ['@CristianSanchez-zs1hz', '@baoef284', '@psychoticnmina']
#   Community 551 (2 users): ['@no_body-theunkown', '@Cinder_souls_10']
#   Community 552 (5 users): ['@HiddenStrengthTimelapseDrawing', '@BIGTHANKSHEESH', '@luigisuperfan4536']
#   Community 553 (2 users): ['@CryingFoxKomera', '@EthanMullett-l6e']
#   Community 554 (2 users): ['@NoahMurphy-v8o', '@darth_meme_lord2980']
#   Community 555 (4 users): ['@realbillsf', '@Zartbart.2012', '@wsg_vallen']
#   Community 556 (2 users): ['@RoomtemperatureIQ-z5v', '@Danimal843']
#   Community 557 (10 users): ['@kaydenl6836', '@Meowmeowwoof.x', '@Ehdjdhdh']
#   Community 558 (6 users): ['@Paulsaladinomd', '@Antassium', '@mathiasfrandsen5468']
#   Community 559 (2 users): ['@mellow_filled', '@ojadventures4770']
#   Community 560 (5 users): ['@joemama-o3q9v', '@Thehubajubaluba', '@bztrd80']
#   Community 561 (3 users): ['@AlexiaDolezal-n6y', '@controlledpower54', '@MidDay__Moon-h6g']
#   Community 562 (2 users): ['@F8isRIPPIN', '@ChrisHimself1357']
#   Community 563 (2 users): ['@Kacky', '@ronny9092']
#   Community 564 (2 users): ['@Iambecksb', '@megnfeller']
#   Community 565 (2 users): ['@theallegedgenius', '@marcmontalvo787']
#   Community 566 (2 users): ['@stack3rrr', '@اليناوجيانامحمد']
#   Community 567 (5 users): ['@WillTennyson', '@Kalefordinner', '@brrryyyy']
#   Community 568 (2 users): ['@zhougongjin2704', '@ebrooks406']
#   Community 569 (2 users): ['@Dorklepuss', '@Ian-xl2xf']
#   Community 570 (4 users): ['@obiwanda', '@senzafine123', '@Peterzach85']
#   Community 571 (1 users): ['@terest-ui9hg']
#   Community 572 (2 users): ['@steveweast475', '@greatadventuresch3281']
#   Community 573 (2 users): ['@dewberry150', '@MalissaThomas']
#   Community 574 (2 users): ['@younganduntalented.7.15', '@masonmurphy956']
#   Community 575 (18 users): ['@foreignuser_', '@JeffC26131', '@alinevieira5435']
#   Community 576 (2 users): ['@peterodriguez2364', '@yddqDD']
#   Community 577 (2 users): ['@Iamam313', '@TonyRea-ok1us']
#   Community 578 (1 users): ['@gek4028']
#   Community 579 (4 users): ['@augusttheduck', '@V3yn', '@Strayhaur48']
#   Community 580 (2 users): ['@josephdillon9698', '@FishMonster112']
#   Community 581 (2 users): ['@Beerbott56', '@WierdestBEAN26']
#   Community 582 (4 users): ['@loverofpasta', '@6GenNativeTexan', '@sweetmilly0w0']
#   Community 583 (1 users): ['@rdragonswan']
#   Community 584 (6 users): ['@JackCornwell-jv2ky', '@clintonbaird5465', '@Shariliaa']
#   Community 585 (2 users): ['@SarahWilcher-s2y', '@sarinavazquez5571']
#   Community 586 (2 users): ['@Martin-Play-The-Beat', '@hyp3r3l3ctric']
#   Community 587 (2 users): ['@MystyTwilight', '@Ali-c6v4k']
#   Community 588 (8 users): ['@ThespianDevil', '@luke8857', '@Espresso_plz']
#   Community 589 (3 users): ['@ELSTR-512', '@theatrekid-with-stagefright', '@SintheMaster']
#   Community 590 (2 users): ['@KingAdjustMadridistaHabsFan24', '@psychodoxie6987']
#   Community 591 (1 users): ['@x_Jadeara']
#   Community 592 (3 users): ['@KatoosaKilla77', '@aiaioioi', '@cupcakecomrade2378']
#   Community 593 (4 users): ['@77xmng', '@Steethan', '@tatvela6915']
#   Community 594 (7 users): ['@NoN053', '@SSnake4425', '@AnnaTownsend-e1r']
#   Community 595 (2 users): ['@domrepcal', '@natcourliss3892']
#   Community 596 (2 users): ['@ihaterv2208', '@cgp1234']
#   Community 597 (3 users): ['@SillyStarCat', '@crippa69', '@HairlessMoleRatx']
#   Community 598 (3 users): ['@Invalidcas', '@JevremijeŠalabala', '@Wilsondaoxygenbreather']
#   Community 599 (1 users): ['@GabrielPerdue-e4e']
#   Community 600 (4 users): ['@rabbitttz', '@EL01-h4c', '@darioradic117']
#   Community 601 (16 users): ['@ur33mom94', '@DJ3TIMELINE2', '@HandleTakenYA']
#   Community 602 (2 users): ['@fingernailafterdark', '@ms22366']
#   Community 603 (4 users): ['@Drberg', '@oliverbrown8038', '@boatdoctors']
#   Community 604 (2 users): ['@watadawgdoin', '@TheSlimMan']
#   Community 605 (2 users): ['@Babydeuck77', '@sharellesmithfy8507']
#   Community 606 (2 users): ['@HamzaHamouch-d9b', '@gregpravednikov1472']
#   Community 607 (2 users): ['@GoodGolly.MissLolly', '@jacquelinesharpe5991']
#   Community 608 (3 users): ['@EldenLord00', '@ew827805', '@Kl6784zu']
#   Community 609 (2 users): ['@samuncle1170', '@misstramaine1981']
#   Community 610 (3 users): ['@Lulu-xl5cm', '@isabelledabadiedelurbe3442', '@MsBiz888']
#   Community 611 (2 users): ['@parkers_path', '@shaikhomaranuar6429']
#   Community 612 (2 users): ['@oogabooga9001', '@peterpiper487']
#   Community 613 (2 users): ['@nobodyknows730', '@БорисФомин-п4ж']
#   Community 614 (3 users): ['@BecomingGeorge', '@lidiaolejnik4723', '@fabinho909090']
#   Community 615 (1 users): ['@DebbieHofstra']
#   Community 616 (5 users): ['@anthonychaffeemd', '@david2cu901', '@realchurchtalk']
#   Community 617 (2 users): ['@boxerjjp9416', '@TaraWoodruff2014']
#   Community 618 (5 users): ['@amandah2490', '@tjan3938', '@LookBeyondTheillusion']
#   Community 619 (2 users): ['@Jst4vdeos', '@Riding_Again']
#   Community 620 (2 users): ['@robmansfield1241', '@cathleenwedlake4705']
#   Community 621 (2 users): ['@716Kim', '@debraperry4104']
#   Community 622 (2 users): ['@datsrilankandude', '@petadee5141']
#   Community 623 (2 users): ['@heartofselma', '@lat6801']
#   Community 624 (12 users): ['@Homesteadhow', '@heyborttheeditor1608', '@ClintJohnson-w7y']
#   Community 625 (2 users): ['@VENOUSUS', '@mattnewland8963']
#   Community 626 (5 users): ['@janelleg597', '@bobbiholliday5961', '@Livefire7']
#   Community 627 (2 users): ['@Paul-w9r1r', '@Hacker-xe8yv']
#   Community 628 (2 users): ['@susanhoffman8', '@dansu3135']
#   Community 629 (1 users): ['@Rogan205']
#   Community 630 (2 users): ['@Noradustoflight', '@marcreyes7474']
#   Community 631 (3 users): ['@TheHellreaper25', '@crass1943', '@iridescent_icecube']
#   Community 632 (1 users): ['@zaptrap01']
#   Community 633 (2 users): ['@ambrosiahasnevertastedthis3673', '@kolainshepherd1032']
#   Community 634 (2 users): ['@minibikerguy', '@nmkflvpttt']
#   Community 635 (2 users): ['@dylanleach1604', '@julienoted']
#   Community 636 (2 users): ['@SeanHartnett-t8c', '@IAmTheStig32']
#   Community 637 (13 users): ['@yangtse55', '@SoggyBarkTree', '@Ballistic_Rice74']
#   Community 638 (4 users): ['@Violet-ui', '@TheMockedy', '@JesusChrist0001BC']
#   Community 639 (3 users): ['@orirune3079', '@halfdeadhomo2967', '@Ellie.chaos007']
#   Community 640 (2 users): ['@tortachlamydia', '@sevenfacedsin']
#   Community 641 (6 users): ['@homesteadingwithPJ', '@hvp6218', '@bruceh4833']
#   Community 642 (2 users): ['@jpsphoto-vision8803', '@robertdick6319']
#   Community 643 (3 users): ['@Gunter_Severloh', '@Rid3thetig3r', '@rhondabaldwin7529']
#   Community 644 (2 users): ['@katharina...', '@michaelgmcauliffe']
#   Community 645 (5 users): ['@mikewood3203', '@DwFritz23', '@BeckieBooBoo']
#   Community 646 (2 users): ['@Kat-n-Ollie', '@wonderfulgood2010']
#   Community 647 (2 users): ['@craiglearner9853', '@pdxoregon1']
#   Community 648 (5 users): ['@dapawap', '@Clirene', '@suzannebroberg1290']
#   Community 649 (3 users): ['@brucewayne1662', '@donnasparks2790', '@andiebrit65']
#   Community 650 (2 users): ['@Miss_Kisa94', '@yhjitsh']
#   Community 651 (2 users): ['@nin6246', '@ironmaidenfitness654']
#   Community 652 (9 users): ['@HelenEk7', '@hezuikn', '@magnolilies1']
#   Community 653 (2 users): ['@YouTubeCommentsHav2ManyRacists', '@gabrielachouja4524']
#   Community 654 (2 users): ['@johnh.7046', '@seitanbeatsyourmeat666']
#   Community 655 (3 users): ['@hopeard3512', '@micherri560', '@wintersprite']
#   Community 656 (2 users): ['@ThisCharmingBat', '@guitarmuso1']
#   Community 657 (2 users): ['@susiemiller2621', '@Thehikerx2']
#   Community 658 (2 users): ['@menemenetekelupharsin-dan55', '@Missygirl1103']
#   Community 659 (2 users): ['@LeavingYoutubeSoon', '@stephenstuckey']
#   Community 660 (2 users): ['@9size2me', '@Douglas-up2vh']
#   Community 661 (2 users): ['@wordsofaction-christianfic4102', '@steve1084']
#   Community 662 (2 users): ['@HRML813', '@Saviorsgrace']
#   Community 663 (3 users): ['@jonnyfranz', '@teefthzsf2', '@Sarah-th5vb']
#   Community 664 (1 users): ['@matthewzompero8441']
#   Community 665 (2 users): ['@IsitsafeIsitsafe', '@nerdcreatives2208']
#   Community 666 (2 users): ['@212019156', '@Robinhood179']
#   Community 667 (2 users): ['@janesawyer3495', '@ann7856']
#   Community 668 (4 users): ['@maddien2135', '@jenergy1000', '@greysquirrel3924']
#   Community 669 (4 users): ['@Freddykittycat', '@bobchambers1455', '@danaburgs']
#   Community 670 (3 users): ['@richardsummers6827', '@CambriaCandiceMaria', '@Jack-v5e3m']
#   Community 671 (2 users): ['@TerminatriX86', '@jannellmeagher638']
#   Community 672 (19 users): ['@mkartz6991', '@britz91', '@Kali-Hope']
#   Community 673 (2 users): ['@araleana', '@oli_toomuch']
#   Community 674 (2 users): ['@emilkleis2821', '@mushubeardie']
#   Community 675 (10 users): ['@Jane-lw4jb', '@butwhywouldyoudothat', '@corilane9940']
#   Community 676 (4 users): ['@idkanymoreman8186', '@asarvis', '@jessicah3450']
#   Community 677 (5 users): ['@ThePrimal.Podcast', '@helenedinand1419', '@daleedwards8691']
#   Community 678 (3 users): ['@Epicurious_Me', '@melissa-logic78', '@elbusinesswilliams7398']
#   Community 679 (3 users): ['@AkashicKeeper', '@martinamoser4919', '@LoriP123']
#   Community 680 (2 users): ['@redhead6743', '@kimlangleyart']
#   Community 681 (11 users): ['@hollybishop484', '@nunyabiznezz3856', '@bajone02']
#   Community 682 (2 users): ['@dawnhertz1014', '@sharonhendricks9706']
#   Community 683 (2 users): ['@DeborahMaybay', '@laceyrushworth9823']
#   Community 684 (3 users): ['@bmc348', '@thera9882', '@Katiefollowingjesus']
#   Community 685 (5 users): ['@terrigodfrey8260', '@chavak3497', '@ProseccoLovingClothesHorses']
#   Community 686 (2 users): ['@karolinasoblinskyte1795', '@AchievewithA']
#   Community 687 (3 users): ['@morrisdavis9231', '@chrisring6414', '@bnic9471']
#   Community 688 (2 users): ['@sportysbusiness', '@trudykrieling88']
#   Community 689 (2 users): ['@lindarossouw3489', '@annesummers09']

# %%
#  What label dominates each community? 
# Map user -> video_label from your dataframe
user_label_map = df.groupby("author")["video_label"].agg(
    lambda x: x.value_counts().index[0]  # most common label for that user
).to_dict()

print("\nDominant content type per community:")
for comm_id in sorted(community_counts.keys()):
    members = [node for node, comm in partition.items() if comm == comm_id]
    labels = [user_label_map.get(m, "unknown") for m in members]
    label_counts = Counter(labels)
    dominant = label_counts.most_common(1)[0]
    print(f"  Community {comm_id}: {dominant[0]} ({dominant[1]}/{len(members)} users)")
# Out:
# Dominant content type per community:
#   Community 0: doctor (1/1 users)
#   Community 1: doctor (3/3 users)
#   Community 2: doctor (2/2 users)
#   Community 3: doctor (2/2 users)
#   Community 4: doctor (2/2 users)
#   Community 5: doctor (1/1 users)
#   Community 6: doctor (2/2 users)
#   Community 7: doctor (2/2 users)
#   Community 8: doctor (2/2 users)
#   Community 9: doctor (3/3 users)
#   Community 10: doctor (2/2 users)
#   Community 11: doctor (2/2 users)
#   Community 12: doctor (3/3 users)
#   Community 13: doctor (2/2 users)
#   Community 14: doctor (2/2 users)
#   Community 15: doctor (2/2 users)
#   Community 16: doctor (3/3 users)
#   Community 17: doctor (1/1 users)
#   Community 18: doctor (9/9 users)
#   Community 19: doctor (5/7 users)
#   Community 20: both (14/16 users)
#   Community 21: both (3/4 users)
#   Community 22: both (2/2 users)
#   Community 23: both (1/2 users)
#   Community 24: both (2/2 users)
#   Community 25: both (2/2 users)
#   Community 26: doctor (5/8 users)
#   Community 27: doctor (2/2 users)
#   Community 28: doctor (2/2 users)
#   Community 29: doctor (2/2 users)
#   Community 30: doctor (1/1 users)
#   Community 31: doctor (1/2 users)
#   Community 32: both (2/2 users)
#   Community 33: both (2/2 users)
#   Community 34: both (2/2 users)
#   Community 35: doctor (2/2 users)
#   Community 36: doctor (4/4 users)
#   Community 37: doctor (3/3 users)
#   Community 38: doctor (2/2 users)
#   Community 39: both (2/2 users)
#   Community 40: both (2/2 users)
#   Community 41: both (4/4 users)
#   Community 42: both (2/2 users)
#   Community 43: both (2/2 users)
#   Community 44: both (2/2 users)
#   Community 45: both (2/2 users)
#   Community 46: both (2/2 users)
#   Community 47: both (3/3 users)
#   Community 48: doctor (10/10 users)
#   Community 49: doctor (2/2 users)
#   Community 50: doctor (5/5 users)
#   Community 51: doctor (2/2 users)
#   Community 52: doctor (2/2 users)
#   Community 53: both (12/13 users)
#   Community 54: both (10/10 users)
#   Community 55: both (7/7 users)
#   Community 56: both (3/3 users)
#   Community 57: both (2/2 users)
#   Community 58: both (2/2 users)
#   Community 59: both (2/2 users)
#   Community 60: doctor (6/6 users)
#   Community 61: doctor (6/6 users)
#   Community 62: doctor (5/5 users)
#   Community 63: doctor (5/5 users)
#   Community 64: doctor (2/2 users)
#   Community 65: doctor (1/1 users)
#   Community 66: doctor (2/2 users)
#   Community 67: doctor (5/5 users)
#   Community 68: doctor (2/2 users)
#   Community 69: doctor (2/2 users)
#   Community 70: doctor (26/26 users)
#   Community 71: doctor (2/2 users)
#   Community 72: doctor (1/1 users)
#   Community 73: doctor (2/2 users)
#   Community 74: doctor (2/2 users)
#   Community 75: doctor (2/2 users)
#   Community 76: doctor (2/2 users)
#   Community 77: doctor (2/2 users)
#   Community 78: doctor (4/4 users)
#   Community 79: doctor (2/2 users)
#   Community 80: doctor (2/2 users)
#   Community 81: doctor (6/6 users)
#   Community 82: doctor (2/2 users)
#   Community 83: doctor (2/2 users)
#   Community 84: doctor (2/2 users)
#   Community 85: doctor (2/2 users)
#   Community 86: doctor (2/2 users)
#   Community 87: doctor (8/8 users)
#   Community 88: doctor (1/1 users)
#   Community 89: doctor (4/4 users)
#   Community 90: doctor (3/3 users)
#   Community 91: doctor (2/2 users)
#   Community 92: doctor (2/2 users)
#   Community 93: doctor (2/2 users)
#   Community 94: doctor (2/2 users)
#   Community 95: doctor (2/2 users)
#   Community 96: doctor (3/3 users)
#   Community 97: doctor (4/4 users)
#   Community 98: doctor (4/7 users)
#   Community 99: doctor (2/2 users)
#   Community 100: doctor (3/3 users)
#   Community 101: doctor (2/2 users)
#   Community 102: doctor (2/2 users)
#   Community 103: doctor (1/2 users)
#   Community 104: doctor (3/3 users)
#   Community 105: doctor (6/6 users)
#   Community 106: doctor (2/2 users)
#   Community 107: doctor (3/3 users)
#   Community 108: doctor (3/3 users)
#   Community 109: influencer (3/3 users)
#   Community 110: influencer (11/11 users)
#   Community 111: influencer (3/3 users)
#   Community 112: influencer (2/2 users)
#   Community 113: influencer (2/2 users)
#   Community 114: influencer (2/2 users)
#   Community 115: influencer (3/3 users)
#   Community 116: influencer (2/2 users)
#   Community 117: influencer (4/4 users)
#   Community 118: influencer (5/5 users)
#   Community 119: influencer (1/1 users)
#   Community 120: influencer (8/8 users)
#   Community 121: doctor (3/3 users)
#   Community 122: influencer (3/3 users)
#   Community 123: doctor (2/2 users)
#   Community 124: doctor (53/53 users)
#   Community 125: doctor (2/2 users)
#   Community 126: doctor (3/3 users)
#   Community 127: doctor (3/3 users)
#   Community 128: doctor (7/7 users)
#   Community 129: doctor (2/2 users)
#   Community 130: doctor (3/3 users)
#   Community 131: doctor (2/2 users)
#   Community 132: influencer (4/4 users)
#   Community 133: doctor (1/1 users)
#   Community 134: doctor (2/2 users)
#   Community 135: doctor (4/4 users)
#   Community 136: doctor (2/2 users)
#   Community 137: doctor (2/2 users)
#   Community 138: doctor (2/2 users)
#   Community 139: both (5/5 users)
#   Community 140: both (3/3 users)
#   Community 141: both (2/2 users)
#   Community 142: both (12/12 users)
#   Community 143: both (2/2 users)
#   Community 144: both (3/3 users)
#   Community 145: both (2/2 users)
#   Community 146: both (3/3 users)
#   Community 147: both (2/2 users)
#   Community 148: both (2/2 users)
#   Community 149: both (1/1 users)
#   Community 150: both (2/2 users)
#   Community 151: both (2/2 users)
#   Community 152: doctor (2/2 users)
#   Community 153: doctor (2/2 users)
#   Community 154: doctor (2/2 users)
#   Community 155: doctor (5/5 users)
#   Community 156: doctor (2/2 users)
#   Community 157: doctor (6/6 users)
#   Community 158: doctor (3/3 users)
#   Community 159: doctor (2/2 users)
#   Community 160: doctor (4/4 users)
#   Community 161: doctor (2/2 users)
#   Community 162: doctor (1/1 users)
#   Community 163: doctor (2/2 users)
#   Community 164: doctor (2/2 users)
#   Community 165: doctor (2/2 users)
#   Community 166: doctor (4/4 users)
#   Community 167: both (2/2 users)
#   Community 168: both (31/31 users)
#   Community 169: both (1/1 users)
#   Community 170: both (2/2 users)
#   Community 171: both (3/3 users)
#   Community 172: both (2/2 users)
#   Community 173: both (4/4 users)
#   Community 174: both (22/23 users)
#   Community 175: both (2/2 users)
#   Community 176: both (2/2 users)
#   Community 177: both (6/6 users)
#   Community 178: both (5/5 users)
#   Community 179: both (21/21 users)
#   Community 180: both (2/2 users)
#   Community 181: both (2/2 users)
#   Community 182: both (2/2 users)
#   Community 183: both (2/2 users)
#   Community 184: both (2/2 users)
#   Community 185: both (2/2 users)
#   Community 186: both (2/2 users)
#   Community 187: both (2/2 users)
#   Community 188: both (2/2 users)
#   Community 189: both (2/2 users)
#   Community 190: both (2/2 users)
#   Community 191: both (2/2 users)
#   Community 192: both (2/2 users)
#   Community 193: both (2/2 users)
#   Community 194: both (2/2 users)
#   Community 195: both (2/2 users)
#   Community 196: doctor (2/2 users)
#   Community 197: doctor (2/2 users)
#   Community 198: doctor (14/14 users)
#   Community 199: doctor (2/2 users)
#   Community 200: doctor (2/2 users)
#   Community 201: doctor (3/3 users)
#   Community 202: doctor (9/9 users)
#   Community 203: doctor (5/5 users)
#   Community 204: doctor (4/4 users)
#   Community 205: doctor (5/5 users)
#   Community 206: doctor (56/56 users)
#   Community 207: doctor (2/2 users)
#   Community 208: doctor (2/2 users)
#   Community 209: doctor (6/6 users)
#   Community 210: doctor (2/2 users)
#   Community 211: doctor (2/2 users)
#   Community 212: doctor (2/2 users)
#   Community 213: doctor (3/3 users)
#   Community 214: doctor (1/1 users)
#   Community 215: doctor (1/1 users)
#   Community 216: doctor (1/1 users)
#   Community 217: doctor (7/7 users)
#   Community 218: doctor (2/2 users)
#   Community 219: doctor (2/3 users)
#   Community 220: doctor (5/5 users)
#   Community 221: doctor (2/2 users)
#   Community 222: doctor (4/4 users)
#   Community 223: doctor (2/2 users)
#   Community 224: doctor (1/1 users)
#   Community 225: doctor (2/2 users)
#   Community 226: doctor (1/1 users)
#   Community 227: doctor (3/3 users)
#   Community 228: doctor (2/2 users)
#   Community 229: doctor (2/2 users)
#   Community 230: doctor (2/2 users)
#   Community 231: doctor (7/7 users)
#   Community 232: doctor (2/2 users)
#   Community 233: doctor (1/1 users)
#   Community 234: doctor (2/2 users)
#   Community 235: doctor (2/2 users)
#   Community 236: doctor (2/2 users)
#   Community 237: doctor (2/2 users)
#   Community 238: doctor (2/2 users)
#   Community 239: doctor (2/2 users)
#   Community 240: doctor (2/2 users)
#   Community 241: doctor (2/2 users)
#   Community 242: doctor (2/2 users)
#   Community 243: doctor (2/2 users)
#   Community 244: doctor (2/2 users)
#   Community 245: doctor (2/2 users)
#   Community 246: doctor (2/2 users)
#   Community 247: doctor (2/2 users)
#   Community 248: doctor (6/6 users)
#   Community 249: doctor (2/2 users)
#   Community 250: doctor (3/3 users)
#   Community 251: doctor (3/3 users)
#   Community 252: doctor (1/1 users)
#   Community 253: doctor (1/1 users)
#   Community 254: doctor (1/1 users)
#   Community 255: doctor (2/2 users)
#   Community 256: doctor (2/2 users)
#   Community 257: doctor (2/2 users)
#   Community 258: doctor (1/1 users)
#   Community 259: doctor (2/2 users)
#   Community 260: doctor (6/6 users)
#   Community 261: doctor (1/1 users)
#   Community 262: doctor (2/2 users)
#   Community 263: doctor (2/2 users)
#   Community 264: doctor (4/4 users)
#   Community 265: doctor (2/2 users)
#   Community 266: doctor (4/4 users)
#   Community 267: doctor (2/2 users)
#   Community 268: doctor (1/1 users)
#   Community 269: doctor (3/3 users)
#   Community 270: doctor (2/2 users)
#   Community 271: doctor (2/2 users)
#   Community 272: doctor (2/2 users)
#   Community 273: doctor (2/2 users)
#   Community 274: doctor (4/4 users)
#   Community 275: doctor (4/4 users)
#   Community 276: doctor (2/2 users)
#   Community 277: doctor (3/3 users)
#   Community 278: doctor (2/2 users)
#   Community 279: doctor (2/2 users)
#   Community 280: doctor (2/2 users)
#   Community 281: doctor (2/2 users)
#   Community 282: doctor (2/2 users)
#   Community 283: both (3/3 users)
#   Community 284: both (1/1 users)
#   Community 285: doctor (2/2 users)
#   Community 286: doctor (5/5 users)
#   Community 287: doctor (6/6 users)
#   Community 288: doctor (1/1 users)
#   Community 289: doctor (2/2 users)
#   Community 290: doctor (1/1 users)
#   Community 291: doctor (6/6 users)
#   Community 292: doctor (2/2 users)
#   Community 293: doctor (1/1 users)
#   Community 294: doctor (1/1 users)
#   Community 295: doctor (1/1 users)
#   Community 296: doctor (2/2 users)
#   Community 297: both (1/1 users)
#   Community 298: both (2/2 users)
#   Community 299: both (2/2 users)
#   Community 300: both (2/2 users)
#   Community 301: both (2/2 users)
#   Community 302: doctor (1/1 users)
#   Community 303: doctor (1/1 users)
#   Community 304: doctor (1/1 users)
#   Community 305: doctor (3/3 users)
#   Community 306: doctor (2/2 users)
#   Community 307: doctor (1/1 users)
#   Community 308: doctor (2/2 users)
#   Community 309: doctor (2/2 users)
#   Community 310: doctor (4/4 users)
#   Community 311: doctor (2/2 users)
#   Community 312: doctor (2/2 users)
#   Community 313: doctor (3/3 users)
#   Community 314: doctor (2/2 users)
#   Community 315: doctor (4/4 users)
#   Community 316: doctor (2/2 users)
#   Community 317: doctor (1/1 users)
#   Community 318: doctor (2/2 users)
#   Community 319: doctor (3/3 users)
#   Community 320: doctor (4/4 users)
#   Community 321: doctor (1/1 users)
#   Community 322: doctor (2/2 users)
#   Community 323: doctor (2/2 users)
#   Community 324: doctor (2/2 users)
#   Community 325: doctor (2/2 users)
#   Community 326: doctor (1/1 users)
#   Community 327: doctor (2/2 users)
#   Community 328: doctor (2/2 users)
#   Community 329: doctor (1/1 users)
#   Community 330: doctor (1/1 users)
#   Community 331: doctor (2/2 users)
#   Community 332: doctor (1/1 users)
#   Community 333: doctor (2/2 users)
#   Community 334: doctor (3/3 users)
#   Community 335: doctor (2/2 users)
#   Community 336: doctor (2/2 users)
#   Community 337: doctor (2/2 users)
#   Community 338: doctor (2/2 users)
#   Community 339: doctor (3/3 users)
#   Community 340: doctor (5/5 users)
#   Community 341: doctor (2/2 users)
#   Community 342: doctor (4/4 users)
#   Community 343: doctor (1/1 users)
#   Community 344: doctor (2/2 users)
#   Community 345: doctor (4/4 users)
#   Community 346: doctor (4/4 users)
#   Community 347: doctor (2/2 users)
#   Community 348: doctor (3/3 users)
#   Community 349: doctor (1/1 users)
#   Community 350: doctor (1/1 users)
#   Community 351: doctor (1/1 users)
#   Community 352: doctor (1/1 users)
#   Community 353: doctor (2/2 users)
#   Community 354: doctor (2/2 users)
#   Community 355: doctor (3/3 users)
#   Community 356: doctor (2/2 users)
#   Community 357: doctor (2/2 users)
#   Community 358: doctor (3/3 users)
#   Community 359: doctor (2/2 users)
#   Community 360: doctor (3/3 users)
#   Community 361: doctor (1/1 users)
#   Community 362: doctor (4/4 users)
#   Community 363: doctor (2/2 users)
#   Community 364: doctor (6/6 users)
#   Community 365: doctor (2/2 users)
#   Community 366: doctor (2/2 users)
#   Community 367: doctor (2/2 users)
#   Community 368: doctor (1/1 users)
#   Community 369: doctor (2/2 users)
#   Community 370: doctor (1/1 users)
#   Community 371: doctor (1/1 users)
#   Community 372: doctor (1/1 users)
#   Community 373: doctor (2/2 users)
#   Community 374: doctor (2/2 users)
#   Community 375: doctor (1/1 users)
#   Community 376: doctor (2/2 users)
#   Community 377: doctor (3/3 users)
#   Community 378: doctor (3/3 users)
#   Community 379: doctor (2/2 users)
#   Community 380: doctor (2/2 users)
#   Community 381: doctor (2/2 users)
#   Community 382: doctor (2/2 users)
#   Community 383: doctor (2/2 users)
#   Community 384: doctor (2/2 users)
#   Community 385: doctor (4/4 users)
#   Community 386: doctor (2/2 users)
#   Community 387: doctor (3/3 users)
#   Community 388: doctor (2/2 users)
#   Community 389: doctor (1/1 users)
#   Community 390: doctor (2/2 users)
#   Community 391: doctor (2/2 users)
#   Community 392: doctor (2/2 users)
#   Community 393: doctor (2/2 users)
#   Community 394: doctor (2/2 users)
#   Community 395: doctor (2/2 users)
#   Community 396: doctor (4/4 users)
#   Community 397: doctor (3/3 users)
#   Community 398: doctor (2/2 users)
#   Community 399: doctor (1/1 users)
#   Community 400: doctor (1/1 users)
#   Community 401: doctor (3/3 users)
#   Community 402: doctor (3/3 users)
#   Community 403: doctor (2/2 users)
#   Community 404: doctor (2/2 users)
#   Community 405: doctor (2/2 users)
#   Community 406: doctor (2/2 users)
#   Community 407: doctor (2/2 users)
#   Community 408: doctor (2/2 users)
#   Community 409: doctor (2/2 users)
#   Community 410: doctor (3/3 users)
#   Community 411: doctor (5/6 users)
#   Community 412: doctor (2/2 users)
#   Community 413: doctor (2/2 users)
#   Community 414: doctor (2/2 users)
#   Community 415: doctor (1/1 users)
#   Community 416: doctor (17/17 users)
#   Community 417: doctor (2/2 users)
#   Community 418: doctor (2/2 users)
#   Community 419: doctor (2/2 users)
#   Community 420: doctor (3/3 users)
#   Community 421: doctor (2/2 users)
#   Community 422: doctor (2/2 users)
#   Community 423: doctor (2/2 users)
#   Community 424: doctor (2/2 users)
#   Community 425: doctor (2/2 users)
#   Community 426: doctor (4/4 users)
#   Community 427: doctor (2/2 users)
#   Community 428: doctor (2/2 users)
#   Community 429: doctor (1/2 users)
#   Community 430: doctor (2/2 users)
#   Community 431: doctor (2/2 users)
#   Community 432: doctor (4/4 users)
#   Community 433: doctor (5/5 users)
#   Community 434: doctor (1/1 users)
#   Community 435: doctor (1/1 users)
#   Community 436: doctor (2/2 users)
#   Community 437: doctor (2/2 users)
#   Community 438: doctor (3/3 users)
#   Community 439: doctor (13/13 users)
#   Community 440: doctor (2/2 users)
#   Community 441: doctor (4/4 users)
#   Community 442: doctor (4/4 users)
#   Community 443: doctor (3/3 users)
#   Community 444: doctor (2/2 users)
#   Community 445: doctor (1/1 users)
#   Community 446: doctor (1/1 users)
#   Community 447: doctor (1/1 users)
#   Community 448: doctor (2/2 users)
#   Community 449: doctor (2/2 users)
#   Community 450: doctor (1/2 users)
#   Community 451: doctor (3/3 users)
#   Community 452: doctor (1/1 users)
#   Community 453: doctor (2/2 users)
#   Community 454: doctor (2/2 users)
#   Community 455: doctor (2/2 users)
#   Community 456: influencer (3/3 users)
#   Community 457: influencer (2/2 users)
#   Community 458: influencer (4/4 users)
#   Community 459: influencer (2/2 users)
#   Community 460: influencer (1/1 users)
#   Community 461: influencer (3/3 users)
#   Community 462: influencer (1/1 users)
#   Community 463: influencer (2/2 users)
#   Community 464: influencer (3/3 users)
#   Community 465: influencer (4/4 users)
#   Community 466: influencer (2/2 users)
#   Community 467: influencer (3/3 users)
#   Community 468: influencer (2/2 users)
#   Community 469: influencer (2/2 users)
#   Community 470: influencer (1/1 users)
#   Community 471: influencer (2/2 users)
#   Community 472: influencer (3/3 users)
#   Community 473: influencer (2/2 users)
#   Community 474: influencer (3/3 users)
#   Community 475: influencer (2/2 users)
#   Community 476: influencer (5/5 users)
#   Community 477: influencer (2/2 users)
#   Community 478: influencer (1/1 users)
#   Community 479: influencer (2/2 users)
#   Community 480: influencer (2/2 users)
#   Community 481: influencer (2/2 users)
#   Community 482: influencer (6/6 users)
#   Community 483: influencer (1/1 users)
#   Community 484: influencer (2/2 users)
#   Community 485: influencer (2/2 users)
#   Community 486: influencer (2/2 users)
#   Community 487: influencer (2/2 users)
#   Community 488: influencer (1/1 users)
#   Community 489: influencer (1/1 users)
#   Community 490: influencer (14/14 users)
#   Community 491: influencer (7/7 users)
#   Community 492: influencer (1/1 users)
#   Community 493: influencer (2/2 users)
#   Community 494: influencer (6/6 users)
#   Community 495: influencer (3/3 users)
#   Community 496: influencer (2/2 users)
#   Community 497: influencer (2/2 users)
#   Community 498: both (31/31 users)
#   Community 499: both (3/3 users)
#   Community 500: both (5/5 users)
#   Community 501: both (2/2 users)
#   Community 502: both (3/3 users)
#   Community 503: both (2/2 users)
#   Community 504: both (1/1 users)
#   Community 505: both (3/3 users)
#   Community 506: both (4/4 users)
#   Community 507: both (4/4 users)
#   Community 508: influencer (3/3 users)
#   Community 509: influencer (2/2 users)
#   Community 510: influencer (1/1 users)
#   Community 511: influencer (2/2 users)
#   Community 512: influencer (2/2 users)
#   Community 513: influencer (36/36 users)
#   Community 514: influencer (2/2 users)
#   Community 515: influencer (2/2 users)
#   Community 516: influencer (4/4 users)
#   Community 517: influencer (2/2 users)
#   Community 518: influencer (2/2 users)
#   Community 519: influencer (2/2 users)
#   Community 520: influencer (2/2 users)
#   Community 521: influencer (2/2 users)
#   Community 522: influencer (2/2 users)
#   Community 523: influencer (2/2 users)
#   Community 524: influencer (6/6 users)
#   Community 525: influencer (2/2 users)
#   Community 526: influencer (5/5 users)
#   Community 527: influencer (4/4 users)
#   Community 528: influencer (3/3 users)
#   Community 529: influencer (6/6 users)
#   Community 530: influencer (6/6 users)
#   Community 531: influencer (5/5 users)
#   Community 532: influencer (5/5 users)
#   Community 533: influencer (1/1 users)
#   Community 534: influencer (2/2 users)
#   Community 535: influencer (3/3 users)
#   Community 536: influencer (1/1 users)
#   Community 537: influencer (2/2 users)
#   Community 538: influencer (4/4 users)
#   Community 539: influencer (4/4 users)
#   Community 540: influencer (2/2 users)
#   Community 541: influencer (2/2 users)
#   Community 542: influencer (3/3 users)
#   Community 543: influencer (4/4 users)
#   Community 544: influencer (2/2 users)
#   Community 545: influencer (3/3 users)
#   Community 546: influencer (6/6 users)
#   Community 547: influencer (2/2 users)
#   Community 548: influencer (5/5 users)
#   Community 549: influencer (2/2 users)
#   Community 550: influencer (6/6 users)
#   Community 551: influencer (2/2 users)
#   Community 552: influencer (5/5 users)
#   Community 553: influencer (1/2 users)
#   Community 554: influencer (2/2 users)
#   Community 555: influencer (4/4 users)
#   Community 556: influencer (2/2 users)
#   Community 557: both (9/10 users)
#   Community 558: both (6/6 users)
#   Community 559: both (2/2 users)
#   Community 560: both (5/5 users)
#   Community 561: both (3/3 users)
#   Community 562: both (2/2 users)
#   Community 563: both (2/2 users)
#   Community 564: both (2/2 users)
#   Community 565: both (1/2 users)
#   Community 566: both (2/2 users)
#   Community 567: influencer (5/5 users)
#   Community 568: influencer (2/2 users)
#   Community 569: influencer (2/2 users)
#   Community 570: influencer (4/4 users)
#   Community 571: influencer (1/1 users)
#   Community 572: influencer (2/2 users)
#   Community 573: influencer (2/2 users)
#   Community 574: influencer (2/2 users)
#   Community 575: influencer (18/18 users)
#   Community 576: influencer (2/2 users)
#   Community 577: influencer (2/2 users)
#   Community 578: influencer (1/1 users)
#   Community 579: influencer (4/4 users)
#   Community 580: influencer (2/2 users)
#   Community 581: influencer (2/2 users)
#   Community 582: influencer (4/4 users)
#   Community 583: influencer (1/1 users)
#   Community 584: influencer (5/6 users)
#   Community 585: influencer (2/2 users)
#   Community 586: influencer (2/2 users)
#   Community 587: influencer (2/2 users)
#   Community 588: influencer (7/8 users)
#   Community 589: influencer (3/3 users)
#   Community 590: influencer (2/2 users)
#   Community 591: influencer (1/1 users)
#   Community 592: influencer (3/3 users)
#   Community 593: influencer (4/4 users)
#   Community 594: influencer (7/7 users)
#   Community 595: influencer (2/2 users)
#   Community 596: influencer (2/2 users)
#   Community 597: influencer (3/3 users)
#   Community 598: influencer (3/3 users)
#   Community 599: influencer (1/1 users)
#   Community 600: influencer (4/4 users)
#   Community 601: influencer (16/16 users)
#   Community 602: influencer (2/2 users)
#   Community 603: both (4/4 users)
#   Community 604: both (2/2 users)
#   Community 605: both (2/2 users)
#   Community 606: both (2/2 users)
#   Community 607: both (2/2 users)
#   Community 608: both (3/3 users)
#   Community 609: both (2/2 users)
#   Community 610: both (3/3 users)
#   Community 611: both (2/2 users)
#   Community 612: both (2/2 users)
#   Community 613: both (2/2 users)
#   Community 614: both (3/3 users)
#   Community 615: both (1/1 users)
#   Community 616: influencer (5/5 users)
#   Community 617: influencer (2/2 users)
#   Community 618: influencer (5/5 users)
#   Community 619: influencer (2/2 users)
#   Community 620: influencer (2/2 users)
#   Community 621: influencer (2/2 users)
#   Community 622: influencer (2/2 users)
#   Community 623: influencer (2/2 users)
#   Community 624: influencer (12/12 users)
#   Community 625: influencer (2/2 users)
#   Community 626: influencer (5/5 users)
#   Community 627: influencer (2/2 users)
#   Community 628: influencer (2/2 users)
#   Community 629: influencer (1/1 users)
#   Community 630: influencer (2/2 users)
#   Community 631: influencer (3/3 users)
#   Community 632: influencer (1/1 users)
#   Community 633: influencer (2/2 users)
#   Community 634: influencer (2/2 users)
#   Community 635: influencer (2/2 users)
#   Community 636: influencer (2/2 users)
#   Community 637: influencer (13/13 users)
#   Community 638: influencer (4/4 users)
#   Community 639: influencer (3/3 users)
#   Community 640: influencer (2/2 users)
#   Community 641: influencer (6/6 users)
#   Community 642: influencer (2/2 users)
#   Community 643: influencer (3/3 users)
#   Community 644: influencer (2/2 users)
#   Community 645: influencer (5/5 users)
#   Community 646: influencer (2/2 users)
#   Community 647: influencer (2/2 users)
#   Community 648: both (4/5 users)
#   Community 649: both (3/3 users)
#   Community 650: both (2/2 users)
#   Community 651: both (2/2 users)
#   Community 652: both (9/9 users)
#   Community 653: both (2/2 users)
#   Community 654: both (2/2 users)
#   Community 655: both (3/3 users)
#   Community 656: influencer (2/2 users)
#   Community 657: influencer (2/2 users)
#   Community 658: influencer (2/2 users)
#   Community 659: influencer (2/2 users)
#   Community 660: influencer (2/2 users)
#   Community 661: influencer (2/2 users)
#   Community 662: influencer (2/2 users)
#   Community 663: doctor (2/3 users)
#   Community 664: doctor (1/1 users)
#   Community 665: doctor (2/2 users)
#   Community 666: doctor (2/2 users)
#   Community 667: doctor (2/2 users)
#   Community 668: both (4/4 users)
#   Community 669: both (4/4 users)
#   Community 670: both (3/3 users)
#   Community 671: both (2/2 users)
#   Community 672: influencer (19/19 users)
#   Community 673: influencer (2/2 users)
#   Community 674: influencer (2/2 users)
#   Community 675: influencer (10/10 users)
#   Community 676: influencer (4/4 users)
#   Community 677: influencer (5/5 users)
#   Community 678: influencer (3/3 users)
#   Community 679: influencer (3/3 users)
#   Community 680: influencer (2/2 users)
#   Community 681: influencer (11/11 users)
#   Community 682: influencer (2/2 users)
#   Community 683: influencer (2/2 users)
#   Community 684: influencer (3/3 users)
#   Community 685: influencer (5/5 users)
#   Community 686: influencer (2/2 users)
#   Community 687: influencer (3/3 users)
#   Community 688: influencer (2/2 users)
#   Community 689: influencer (2/2 users)

# %%
# ── Visualise Communities ─────────────────────────────────────────────────
# Use top 200 nodes to keep it readable
top_nodes = sorted(G_undirected.degree(), key=lambda x: -x[1])[:200]
top_nodes = [n for n, _ in top_nodes]
subgraph = G_undirected.subgraph(top_nodes)

# colour nodes by community
community_colors = [partition.get(node, 0) for node in subgraph.nodes()]
pos = nx.kamada_kawai_layout(subgraph)
node_sizes = [subgraph.degree(n) * 10 for n in subgraph.nodes()]

plt.figure(figsize=(14, 10))
nx.draw(
    subgraph, pos,
    node_color=community_colors,
    cmap=plt.cm.tab10,
    node_size=node_sizes,
    edge_color="gray",
    alpha=0.7,
    with_labels=False
)
plt.title("User Interaction Network — Coloured by Community (Louvain)")
plt.savefig("community_network.png", dpi=150, bbox_inches="tight")
plt.show()
print("Community detection complete!")
# Out:
# Community detection complete!

# %%
#Visualising the User Interaction Network of the Most Connected Users

# Select the top 30 users with the highest number of connections.
top_nodes = sorted(G.degree, key=lambda x: x[1], reverse=True)[:30]
# Extract only the usernames from the degree results.
top_nodes = [n[0] for n in top_nodes]

# Create a smaller subgraph containing only the top connected users.
subgraph = G.subgraph(top_nodes)

# Generate positions for the network visualisation.
# Kamada-Kawai layout helps spread nodes clearly based on their connections.
pos = nx.kamada_kawai_layout(subgraph)

# Set node sizes based on the number of connections each user has.
# More connected users appear larger in the graph.
node_sizes = [G.degree(n) * 50 for n in subgraph.nodes()]

plt.figure(figsize=(8,6))
nx.draw(subgraph, pos, node_size=node_sizes, with_labels=False)

plt.title("User Interaction Network (Top Users)")
plt.show()

# %%
#Visualising the User Interaction Network Using a Circular Layout

# Select the top 50 users with the highest number of connections.
top_nodes = sorted(G.degree, key=lambda x: x[1], reverse=True)[:50]

# Extract only the usernames from the degree results.
top_nodes = [n[0] for n in top_nodes]

# Create a smaller subgraph containing only the top connected users.
subgraph = G.subgraph(top_nodes)

# Generate positions for the nodes using a circular layout.
# This arranges all users around a circle for a cleaner visual structure.
pos = nx.circular_layout(subgraph)


plt.figure(figsize=(8,6))
nx.draw(subgraph, pos, node_size=50, with_labels=False)

plt.title("User Interaction Network (Circular Layout)")
plt.show()
